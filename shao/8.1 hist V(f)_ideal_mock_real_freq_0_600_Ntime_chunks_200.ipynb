# %% [markdown]
# ## Results for Long-Time Flagging Patterns
#
# * For both the `narrowband_long_time` and `wideband_long_time` flagging patterns, the `2d_1d` method achieves an RMS approximately one order of magnitude lower than those of the `1d_1d` across all tested baselines: `(0, 1)`, `(0, 5)`, and `(0, 10)`.
#
# * This result remains stable across different time-chunk configurations, with `Ntime_chunks` ranging from 50 to 800, as well as across the frequency ranges `freq_150_500`, `freq_200_450`, and `freq_250_400`.

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import numpy as np
import pandas as pd
import torch
from pathlib import Path

import sys
sys.path.append("./")

from utils_load import load_hist_residual


# ============================================================
# Settings
# ============================================================

torch.set_default_dtype(torch.float64)

time_ints = range(80, 1680)
polsi = "ee"
add_real_flags = False

blall = [(0, 1), (0, 5), (0, 10)]

inpaint_method_all = ["2d_1d", "1d_1d", "freq"]

flag_types_all = [
    "narrowband_full_time",
    "wideband_full_time",
    "ultraband_short_time",
    "fullband_short_time",
    "narrowband_short_time",
    "narrowband_long_time",
    "wideband_long_time",
    "randn",
]


# ============================================================
# Frequency and time-chunk configurations
# ============================================================

configurations = [
    {"label": "freq_0_600, chunks_50", "freq_chans": range(0, 600), "Ntime_chunks": 50},
    {"label": "freq_0_600, chunks_100", "freq_chans": range(0, 600), "Ntime_chunks": 100},
    {"label": "freq_0_600, chunks_200", "freq_chans": range(0, 600), "Ntime_chunks": 200},
    {"label": "freq_0_600, chunks_400", "freq_chans": range(0, 600), "Ntime_chunks": 400},
    {"label": "freq_0_600, chunks_800", "freq_chans": range(0, 600), "Ntime_chunks": 800},
    {"label": "freq_150_500, chunks_200", "freq_chans": range(150, 500), "Ntime_chunks": 200},
    {"label": "freq_200_450, chunks_200", "freq_chans": range(200, 450), "Ntime_chunks": 200},
    {"label": "freq_250_400, chunks_200", "freq_chans": range(250, 400), "Ntime_chunks": 200},
]


# ============================================================
# Plot settings
# ============================================================

root_dir = "hist_residual"

hist_bins = 80
hist_quantile = 0.995
display_fraction_x = 0.8

save_figures = True
save_tables = True

figure_dir = Path("hist_comparison_figures")
table_dir = Path("hist_comparison_tables")

figure_dir.mkdir(parents=True, exist_ok=True)
table_dir.mkdir(parents=True, exist_ok=True)

# Line styles for histogram configurations
hist_linestyles = [
    "-",
    "--",
    "-.",
    ":",
    (0, (5, 1)),
    (0, (3, 1, 1, 1)),
    (0, (1, 1)),
    (0, (5, 2, 1, 2)),
]

# Line styles and markers for inpainting methods
method_linestyles = ["-", "--", "-."]
method_markers = ["o", "s", "^"]


# ============================================================
# Helper functions
# ============================================================

def get_flag_title(flag_typesi, add_real_flags):
    if flag_typesi is None:
        return "Real Flags" if add_real_flags else "No Flags"

    title = flag_typesi.replace("_", " ").title()
    return f"Real Flags + {title}" if add_real_flags else title


def clean_hist_values(hist_residual):
    values = hist_residual.detach().cpu().reshape(-1).numpy()
    return values[np.isfinite(values)]


def calculate_statistics(values):
    if values.size == 0:
        return np.nan, np.nan, np.nan, 0

    mean = np.mean(values)
    std = np.std(values, ddof=1) if values.size > 1 else 0.0
    rmse = np.sqrt(np.mean(values**2))

    return mean, std, rmse, values.size


# ============================================================
# Main loop
# ============================================================

all_statistics = []

for bl in blall:

    nrows = len(flag_types_all)
    ncols = len(inpaint_method_all) + 2

    fig, axes = plt.subplots(nrows, ncols, figsize=(4.2 * ncols, 3.1 * nrows), squeeze=False)

    baseline_statistics = []

    for row_idx, flag_typesi in enumerate(flag_types_all):

        flag_title = get_flag_title(flag_typesi, add_real_flags)
        flag_results = {}

        # ========================================================
        # Load all histogram results for this flag
        # ========================================================

        for inpaint_methodi in inpaint_method_all:

            flag_results[inpaint_methodi] = []

            for config_idx, config in enumerate(configurations):

                hist_residual = load_hist_residual(
                    bl=bl, flag_typesi=flag_typesi, add_real_flags=add_real_flags,
                    inpaint_method=inpaint_methodi, freq_chans=config["freq_chans"],
                    time_ints=time_ints, polsi=polsi, Ntime_chunks=config["Ntime_chunks"],
                    root_dir=root_dir, device="cpu",
                )

                values = clean_hist_values(hist_residual)
                mean, std, rmse, sample_number = calculate_statistics(values)

                result = {
                    "config_idx": config_idx,
                    "label": config["label"],
                    "freq_start": config["freq_chans"].start,
                    "freq_stop": config["freq_chans"].stop,
                    "Ntime_chunks": config["Ntime_chunks"],
                    "values": values,
                    "mean": mean,
                    "std": std,
                    "rmse": rmse,
                    "N": sample_number,
                }

                flag_results[inpaint_methodi].append(result)

                baseline_statistics.append({
                    "baseline": str(bl),
                    "polarization": polsi,
                    "flag": flag_typesi,
                    "method": inpaint_methodi,
                    "config_number": config_idx + 1,
                    "configuration": config["label"],
                    "freq_start": config["freq_chans"].start,
                    "freq_stop": config["freq_chans"].stop,
                    "Ntime_chunks": config["Ntime_chunks"],
                    "N": sample_number,
                    "mean": mean,
                    "std": std,
                    "rmse": rmse,
                })

        # ========================================================
        # Column 1: RMSE versus Ntime_chunks
        # Only use frequency channels 0–600
        # ========================================================

        ax_chunk = axes[row_idx, 0]

        for method_idx, inpaint_methodi in enumerate(inpaint_method_all):

            chunk_results = [
                result for result in flag_results[inpaint_methodi]
                if result["freq_start"] == 0 and result["freq_stop"] == 600
            ]

            chunk_results = sorted(chunk_results, key=lambda result: result["Ntime_chunks"])

            chunk_x = [result["Ntime_chunks"] for result in chunk_results]
            chunk_rmse = [result["rmse"] for result in chunk_results]

            ax_chunk.plot(
                chunk_x, chunk_rmse,
                marker=method_markers[method_idx % len(method_markers)],
                linestyle=method_linestyles[method_idx % len(method_linestyles)],
                linewidth=1.8, markersize=6, markerfacecolor="none",
                markeredgewidth=1.2, label=inpaint_methodi, zorder=method_idx + 2,
            )

        ax_chunk.set_xscale("log", base=2)
        ax_chunk.set_yscale("log")

        ax_chunk.set_xticks([50, 100, 200, 400, 800])
        ax_chunk.set_xticklabels(["50", "100", "200", "400", "800"])

        ax_chunk.set_xlabel("Ntime chunks", fontsize=10)
        ax_chunk.set_ylabel(f"{flag_title}\nResidual RMSE", fontsize=10)

        ax_chunk.tick_params(axis="both", labelsize=8)
        ax_chunk.grid(True, which="both", alpha=0.25)

        if row_idx == 0:
            ax_chunk.set_title("RMSE vs Chunks\nFreq 0–600", fontsize=12, fontweight="bold")
            ax_chunk.legend(fontsize=8, loc="best", handlelength=2.5)

        # ========================================================
        # Column 2: RMSE versus frequency range
        # Only use Ntime_chunks = 200
        # ========================================================

        ax_freq = axes[row_idx, 1]

        freq_configs = [(0, 600), (150, 500), (200, 450), (250, 400)]

        freq_positions = np.arange(len(freq_configs))
        freq_labels = [f"{start}–{stop}" for start, stop in freq_configs]

        for method_idx, inpaint_methodi in enumerate(inpaint_method_all):

            freq_results = []

            for freq_start, freq_stop in freq_configs:

                matching_results = [
                    result for result in flag_results[inpaint_methodi]
                    if result["freq_start"] == freq_start
                    and result["freq_stop"] == freq_stop
                    and result["Ntime_chunks"] == 200
                ]

                freq_results.append(matching_results[0] if matching_results else None)

            freq_rmse = [
                result["rmse"] if result is not None else np.nan
                for result in freq_results
            ]

            ax_freq.plot(
                freq_positions, freq_rmse,
                marker=method_markers[method_idx % len(method_markers)],
                linestyle=method_linestyles[method_idx % len(method_linestyles)],
                linewidth=1.8, markersize=6, markerfacecolor="none",
                markeredgewidth=1.2, label=inpaint_methodi, zorder=method_idx + 2,
            )

        ax_freq.set_yscale("log")

        ax_freq.set_xticks(freq_positions)
        ax_freq.set_xticklabels(freq_labels, rotation=30, ha="right")

        ax_freq.set_xlabel("Frequency channels", fontsize=10)
        ax_freq.set_ylabel("Residual RMSE", fontsize=10)

        ax_freq.tick_params(axis="both", labelsize=8)
        ax_freq.grid(True, which="both", alpha=0.25)

        if row_idx == 0:
            ax_freq.set_title("RMSE vs Frequency\nChunks 200", fontsize=12, fontweight="bold")
            ax_freq.legend(fontsize=8, loc="best", handlelength=2.5)

        # ========================================================
        # Remaining columns: histogram for each algorithm
        # ========================================================

        for method_idx, inpaint_methodi in enumerate(inpaint_method_all):

            ax = axes[row_idx, method_idx + 2]
            subplot_results = flag_results[inpaint_methodi]

            valid_arrays = [
                result["values"]
                for result in subplot_results
                if result["values"].size > 0
            ]

            if not valid_arrays:
                ax.text(0.5, 0.5, "No data", ha="center", va="center", transform=ax.transAxes)
                continue

            hist_all = np.concatenate(valid_arrays)
            hist_limit = np.quantile(np.abs(hist_all), hist_quantile)

            if not np.isfinite(hist_limit) or hist_limit <= 0:
                hist_limit = np.max(np.abs(hist_all))

            if not np.isfinite(hist_limit) or hist_limit <= 0:
                hist_limit = 1.0

            x_limit = hist_limit * display_fraction_x

            for result in subplot_results:

                if result["values"].size == 0:
                    continue

                config_idx = result["config_idx"]

                ax.hist(
                    result["values"], bins=hist_bins, range=(-hist_limit, hist_limit),
                    density=True, histtype="step", linewidth=1.8,
                    linestyle=hist_linestyles[config_idx % len(hist_linestyles)],
                    label=str(config_idx + 1), zorder=config_idx + 1,
                )

            ax.axvline(0, color="k", linestyle="--", linewidth=0.8)

            ax.set_xlim(-x_limit, x_limit)
            ax.set_yscale("log")

            ax.tick_params(axis="both", labelsize=8)

            ax.legend(
                fontsize=6, loc="upper right", frameon=True, handlelength=2.0,
                labelspacing=0.2, borderpad=0.3, ncol=2,
            )

            if row_idx == nrows - 1:
                ax.set_xlabel(
                    r"$(|V_{\mathrm{inp}}|-|V_{\mathrm{true}}|)/|V_{\mathrm{true}}|$",
                    fontsize=10,
                )

            if method_idx == 0:
                ax.set_ylabel("Density", fontsize=10)

            if row_idx == 0:
                ax.set_title(inpaint_methodi, fontsize=13, fontweight="bold")

    # ========================================================
    # Configuration legend outside all subplots
    # ========================================================

    configuration_handles = [
        Line2D(
            [0], [0], color="black", linewidth=1.8,
            linestyle=hist_linestyles[i % len(hist_linestyles)],
            label=f"{i + 1}: {config['label']}",
        )
        for i, config in enumerate(configurations)
    ]

    fig.legend(
        handles=configuration_handles, loc="upper center",
        bbox_to_anchor=(0.5, 0.972), ncol=4, fontsize=8,
        frameon=True, handlelength=2.5, columnspacing=1.5,
    )

    # ========================================================
    # Figure formatting
    # ========================================================

    fig.suptitle(f"Baseline {bl}, Pol {polsi}", fontsize=16, y=0.998)

    fig.subplots_adjust(
        top=0.90, bottom=0.06, left=0.07, right=0.99,
        hspace=0.40, wspace=0.32,
    )

    if save_figures:
        figure_name = f"hist_rmse_comparison_bl_{bl[0]}_{bl[1]}_pol_{polsi}.png"
        fig.savefig(figure_dir / figure_name, dpi=200, bbox_inches="tight")

    plt.show()
    plt.close(fig)

    # ========================================================
    # Statistics table
    # Smaller RMSE means better
    # ========================================================

    baseline_df = pd.DataFrame(baseline_statistics)

    baseline_df["rank"] = baseline_df.groupby(["flag", "method"])["rmse"].rank(method="min")

    display_columns = [
        "baseline",
        "flag",
        "method",
        "config_number",
        "configuration",
        "freq_start",
        "freq_stop",
        "Ntime_chunks",
        "N",
        "mean",
        "std",
        "rmse",
        "rank",
    ]

    display(
        baseline_df[display_columns]
        .sort_values(["flag", "method", "rank"])
        .reset_index(drop=True)
    )

    # ========================================================
    # Best configuration for each flag and algorithm
    # ========================================================

    best_configuration_df = (
        baseline_df
        .sort_values("rmse")
        .groupby(["flag", "method"], as_index=False)
        .first()
    )

    print(f"\nBest configurations for baseline {bl}:")

    display(
        best_configuration_df[
            [
                "flag",
                "method",
                "config_number",
                "configuration",
                "mean",
                "std",
                "rmse",
            ]
        ]
    )

    if save_tables:

        baseline_df.to_csv(
            table_dir / f"hist_rmse_statistics_bl_{bl[0]}_{bl[1]}_pol_{polsi}.csv",
            index=False,
        )

        best_configuration_df.to_csv(
            table_dir / f"best_rmse_configurations_bl_{bl[0]}_{bl[1]}_pol_{polsi}.csv",
            index=False,
        )

    all_statistics.append(baseline_df)


# ============================================================
# Combined table for all baselines
# ============================================================

if all_statistics:

    all_statistics_df = pd.concat(all_statistics, ignore_index=True)

    all_statistics_df["overall_rank"] = all_statistics_df.groupby(
        ["baseline", "flag", "method"]
    )["rmse"].rank(method="min")

    display(
        all_statistics_df[
            [
                "baseline",
                "flag",
                "method",
                "config_number",
                "configuration",
                "freq_start",
                "freq_stop",
                "Ntime_chunks",
                "N",
                "mean",
                "std",
                "rmse",
                "overall_rank",
            ]
        ]
        .sort_values(["baseline", "flag", "method", "overall_rank"])
        .reset_index(drop=True)
    )

    if save_tables:
        all_statistics_df.to_csv(
            table_dir / f"hist_rmse_statistics_all_baselines_pol_{polsi}.csv",
            index=False,
        )
# Out:
#     baseline                 flag method  config_number  \
# 0     (0, 1)  fullband_short_time  1d_1d              1
# 1     (0, 1)  fullband_short_time  1d_1d              2
# 2     (0, 1)  fullband_short_time  1d_1d              4
# 3     (0, 1)  fullband_short_time  1d_1d              5
# 4     (0, 1)  fullband_short_time  1d_1d              3
# ..       ...                  ...    ...            ...
# 187   (0, 1)   wideband_long_time   freq              2
# 188   (0, 1)   wideband_long_time   freq              3
# 189   (0, 1)   wideband_long_time   freq              4
# 190   (0, 1)   wideband_long_time   freq              5
# 191   (0, 1)   wideband_long_time   freq              6
#
#                 configuration  freq_start  freq_stop  Ntime_chunks      N  \
# 0       freq_0_600, chunks_50           0        600            50  12000
# 1      freq_0_600, chunks_100           0        600           100  12000
# 2      freq_0_600, chunks_400           0        600           400  12000
# 3      freq_0_600, chunks_800           0        600           800  12000
# 4      freq_0_600, chunks_200           0        600           200  12000
# ..                        ...         ...        ...           ...    ...
# 187    freq_0_600, chunks_100           0        600           100   7200
# 188    freq_0_600, chunks_200           0        600           200   7200
# 189    freq_0_600, chunks_400           0        600           400   7200
# 190    freq_0_600, chunks_800           0        600           800   7200
# 191  freq_150_500, chunks_200         150        500           200   6600
#
#          mean       std      rmse  rank
# 0   -0.000141  0.001254  0.001262   1.0
# 1   -0.000220  0.001686  0.001700   2.0
# 2   -0.000071  0.001838  0.001840   3.0
# 3   -0.000073  0.001911  0.001912   4.0
# 4   -0.000209  0.001926  0.001938   5.0
# ..        ...       ...       ...   ...
# 187 -0.000562  0.001563  0.001661   3.0
# 188 -0.000562  0.001563  0.001661   5.0
# 189 -0.000562  0.001563  0.001661   5.0
# 190 -0.000562  0.001563  0.001661   5.0
# 191 -0.001881  0.016265  0.016372   8.0
#
# [192 rows x 13 columns]
# Best configurations for baseline (0, 1):
#                      flag method  config_number             configuration  \
# 0     fullband_short_time  1d_1d              1     freq_0_600, chunks_50
# 1     fullband_short_time  2d_1d              1     freq_0_600, chunks_50
# 2     fullband_short_time   freq              2    freq_0_600, chunks_100
# 3    narrowband_full_time  1d_1d              3    freq_0_600, chunks_200
# 4    narrowband_full_time  2d_1d              5    freq_0_600, chunks_800
# 5    narrowband_full_time   freq              5    freq_0_600, chunks_800
# 6    narrowband_long_time  1d_1d              8  freq_250_400, chunks_200
# 7    narrowband_long_time  2d_1d              8  freq_250_400, chunks_200
# 8    narrowband_long_time   freq              8  freq_250_400, chunks_200
# 9   narrowband_short_time  1d_1d              6  freq_150_500, chunks_200
# 10  narrowband_short_time  2d_1d              6  freq_150_500, chunks_200
# 11  narrowband_short_time   freq              6  freq_150_500, chunks_200
# 12                  randn  1d_1d              4    freq_0_600, chunks_400
# 13                  randn  2d_1d              4    freq_0_600, chunks_400
# 14                  randn   freq              4    freq_0_600, chunks_400
# 15   ultraband_short_time  1d_1d              8  freq_250_400, chunks_200
# 16   ultraband_short_time  2d_1d              8  freq_250_400, chunks_200
# 17   ultraband_short_time   freq              7  freq_200_450, chunks_200
# 18     wideband_full_time  1d_1d              5    freq_0_600, chunks_800
# 19     wideband_full_time  2d_1d              4    freq_0_600, chunks_400
# 20     wideband_full_time   freq              3    freq_0_600, chunks_200
# 21     wideband_long_time  1d_1d              5    freq_0_600, chunks_800
# 22     wideband_long_time  2d_1d              8  freq_250_400, chunks_200
# 23     wideband_long_time   freq              8  freq_250_400, chunks_200
#
#         mean       std      rmse
# 0  -0.000141  0.001254  0.001262
# 1   0.000156  0.001231  0.001241
# 2  -1.000000  0.000000  1.000000
# 3  -0.000006  0.000634  0.000634
# 4  -0.000006  0.000632  0.000632
# 5  -0.000006  0.000635  0.000635
# 6  -0.000248  0.000852  0.000888
# 7   0.000073  0.000306  0.000314
# 8   0.000074  0.000308  0.000317
# 9   0.000044  0.000279  0.000282
# 10  0.000044  0.000281  0.000284
# 11  0.000044  0.000281  0.000284
# 12  0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000
# 15  0.000161  0.001017  0.001030
# 16  0.000094  0.000976  0.000980
# 17  0.000768  0.002572  0.002684
# 18 -0.000457  0.003335  0.003366
# 19 -0.000318  0.003271  0.003286
# 20 -0.000458  0.003342  0.003373
# 21 -0.000675  0.001619  0.001754
# 22 -0.000085  0.000791  0.000796
# 23 -0.000004  0.000723  0.000723
#     baseline                 flag method  config_number  \
# 0     (0, 5)  fullband_short_time  1d_1d              2
# 1     (0, 5)  fullband_short_time  1d_1d              1
# 2     (0, 5)  fullband_short_time  1d_1d              8
# 3     (0, 5)  fullband_short_time  1d_1d              7
# 4     (0, 5)  fullband_short_time  1d_1d              6
# ..       ...                  ...    ...            ...
# 187   (0, 5)   wideband_long_time   freq              5
# 188   (0, 5)   wideband_long_time   freq              1
# 189   (0, 5)   wideband_long_time   freq              2
# 190   (0, 5)   wideband_long_time   freq              6
# 191   (0, 5)   wideband_long_time   freq              7
#
#                 configuration  freq_start  freq_stop  Ntime_chunks      N  \
# 0      freq_0_600, chunks_100           0        600           100  12000
# 1       freq_0_600, chunks_50           0        600            50  12000
# 2    freq_250_400, chunks_200         250        400           200   3000
# 3    freq_200_450, chunks_200         200        450           200   5000
# 4    freq_150_500, chunks_200         150        500           200   7000
# ..                        ...         ...        ...           ...    ...
# 187    freq_0_600, chunks_800           0        600           800   7200
# 188     freq_0_600, chunks_50           0        600            50   7200
# 189    freq_0_600, chunks_100           0        600           100   7200
# 190  freq_150_500, chunks_200         150        500           200   6600
# 191  freq_200_450, chunks_200         200        450           200   6600
#
#          mean       std      rmse  rank
# 0   -0.000041  0.001912  0.001912   1.0
# 1   -0.000054  0.001995  0.001995   2.0
# 2   -0.000074  0.002275  0.002276   3.0
# 3   -0.000012  0.002748  0.002747   4.0
# 4    0.000002  0.002849  0.002849   5.0
# ..        ...       ...       ...   ...
# 187 -0.001081  0.005057  0.005171   2.0
# 188 -0.001081  0.005057  0.005171   5.0
# 189 -0.001081  0.005057  0.005171   5.0
# 190  0.002619  0.015987  0.016199   7.0
# 191 -0.004208  0.028785  0.029089   8.0
#
# [192 rows x 13 columns]
# Best configurations for baseline (0, 5):
#                      flag method  config_number             configuration  \
# 0     fullband_short_time  1d_1d              2    freq_0_600, chunks_100
# 1     fullband_short_time  2d_1d              2    freq_0_600, chunks_100
# 2     fullband_short_time   freq              2    freq_0_600, chunks_100
# 3    narrowband_full_time  1d_1d              1     freq_0_600, chunks_50
# 4    narrowband_full_time  2d_1d              4    freq_0_600, chunks_400
# 5    narrowband_full_time   freq              3    freq_0_600, chunks_200
# 6    narrowband_long_time  1d_1d              1     freq_0_600, chunks_50
# 7    narrowband_long_time  2d_1d              7  freq_200_450, chunks_200
# 8    narrowband_long_time   freq              7  freq_200_450, chunks_200
# 9   narrowband_short_time  1d_1d              6  freq_150_500, chunks_200
# 10  narrowband_short_time  2d_1d              6  freq_150_500, chunks_200
# 11  narrowband_short_time   freq              6  freq_150_500, chunks_200
# 12                  randn  1d_1d              7  freq_200_450, chunks_200
# 13                  randn  2d_1d              7  freq_200_450, chunks_200
# 14                  randn   freq              7  freq_200_450, chunks_200
# 15   ultraband_short_time  1d_1d              7  freq_200_450, chunks_200
# 16   ultraband_short_time  2d_1d              7  freq_200_450, chunks_200
# 17   ultraband_short_time   freq              7  freq_200_450, chunks_200
# 18     wideband_full_time  1d_1d              7  freq_200_450, chunks_200
# 19     wideband_full_time  2d_1d              7  freq_200_450, chunks_200
# 20     wideband_full_time   freq              7  freq_200_450, chunks_200
# 21     wideband_long_time  1d_1d              5    freq_0_600, chunks_800
# 22     wideband_long_time  2d_1d              7  freq_200_450, chunks_200
# 23     wideband_long_time   freq              8  freq_250_400, chunks_200
#
#             mean           std          rmse
# 0  -4.065385e-05  1.911909e-03  1.912261e-03
# 1   3.055439e-05  1.678828e-03  1.679037e-03
# 2  -1.000000e+00  0.000000e+00  1.000000e+00
# 3   1.052304e-05  6.473249e-04  6.474004e-04
# 4   1.081777e-05  6.466261e-04  6.467065e-04
# 5   1.035972e-05  6.484176e-04  6.484902e-04
# 6  -1.505156e-03  2.577810e-03  2.984789e-03
# 7  -2.724460e-05  7.465773e-04  7.469819e-04
# 8  -9.941083e-06  7.434611e-04  7.434356e-04
# 9  -1.066367e-04  7.244964e-04  7.314056e-04
# 10 -1.019716e-04  7.325049e-04  7.386611e-04
# 11 -9.851454e-05  7.393580e-04  7.449757e-04
# 12  1.143405e-17  3.519404e-17  3.615836e-17
# 13  1.143405e-17  3.519404e-17  3.615836e-17
# 14  1.143405e-17  3.519404e-17  3.615836e-17
# 15 -4.323900e-05  1.640166e-03  1.640193e-03
# 16  7.520251e-05  1.581587e-03  1.582851e-03
# 17 -8.849026e-03  4.097819e-02  4.190951e-02
# 18 -9.554498e-03  2.437892e-02  2.618431e-02
# 19 -1.600482e-03  1.810616e-02  1.817672e-02
# 20 -9.886953e-03  2.494180e-02  2.682988e-02
# 21 -7.771731e-04  1.013990e-02  1.016894e-02
# 22 -5.805645e-04  2.527666e-03  2.593296e-03
# 23 -4.280616e-04  4.116759e-03  4.138670e-03
#     baseline                 flag method  config_number  \
# 0    (0, 10)  fullband_short_time  1d_1d              8
# 1    (0, 10)  fullband_short_time  1d_1d              1
# 2    (0, 10)  fullband_short_time  1d_1d              2
# 3    (0, 10)  fullband_short_time  1d_1d              3
# 4    (0, 10)  fullband_short_time  1d_1d              6
# ..       ...                  ...    ...            ...
# 187  (0, 10)   wideband_long_time   freq              4
# 188  (0, 10)   wideband_long_time   freq              5
# 189  (0, 10)   wideband_long_time   freq              6
# 190  (0, 10)   wideband_long_time   freq              7
# 191  (0, 10)   wideband_long_time   freq              8
#
#                 configuration  freq_start  freq_stop  Ntime_chunks      N  \
# 0    freq_250_400, chunks_200         250        400           200   3000
# 1       freq_0_600, chunks_50           0        600            50  12000
# 2      freq_0_600, chunks_100           0        600           100  12000
# 3      freq_0_600, chunks_200           0        600           200  12000
# 4    freq_150_500, chunks_200         150        500           200   7000
# ..                        ...         ...        ...           ...    ...
# 187    freq_0_600, chunks_400           0        600           400   7200
# 188    freq_0_600, chunks_800           0        600           800   7200
# 189  freq_150_500, chunks_200         150        500           200   6600
# 190  freq_200_450, chunks_200         200        450           200   6600
# 191  freq_250_400, chunks_200         250        400           200   7200
#
#          mean       std      rmse  rank
# 0   -0.000221  0.002149  0.002160   1.0
# 1   -0.000009  0.006468  0.006468   2.0
# 2   -0.000010  0.007687  0.007687   3.0
# 3   -0.000014  0.021861  0.021860   4.0
# 4    0.000182  0.025586  0.025585   5.0
# ..        ...       ...       ...   ...
# 187  0.000268  0.004020  0.004029   3.0
# 188  0.000268  0.004020  0.004029   3.0
# 189 -0.002644  0.015183  0.015410   6.0
# 190 -0.004001  0.020958  0.021335   7.0
# 191 -0.012423  0.054684  0.056073   8.0
#
# [192 rows x 13 columns]
# Best configurations for baseline (0, 10):
#                      flag method  config_number             configuration  \
# 0     fullband_short_time  1d_1d              8  freq_250_400, chunks_200
# 1     fullband_short_time  2d_1d              8  freq_250_400, chunks_200
# 2     fullband_short_time   freq              2    freq_0_600, chunks_100
# 3    narrowband_full_time  1d_1d              7  freq_200_450, chunks_200
# 4    narrowband_full_time  2d_1d              7  freq_200_450, chunks_200
# 5    narrowband_full_time   freq              7  freq_200_450, chunks_200
# 6    narrowband_long_time  1d_1d              5    freq_0_600, chunks_800
# 7    narrowband_long_time  2d_1d              2    freq_0_600, chunks_100
# 8    narrowband_long_time   freq              5    freq_0_600, chunks_800
# 9   narrowband_short_time  1d_1d              5    freq_0_600, chunks_800
# 10  narrowband_short_time  2d_1d              5    freq_0_600, chunks_800
# 11  narrowband_short_time   freq              2    freq_0_600, chunks_100
# 12                  randn  1d_1d              8  freq_250_400, chunks_200
# 13                  randn  2d_1d              8  freq_250_400, chunks_200
# 14                  randn   freq              8  freq_250_400, chunks_200
# 15   ultraband_short_time  1d_1d              1     freq_0_600, chunks_50
# 16   ultraband_short_time  2d_1d              1     freq_0_600, chunks_50
# 17   ultraband_short_time   freq              5    freq_0_600, chunks_800
# 18     wideband_full_time  1d_1d              7  freq_200_450, chunks_200
# 19     wideband_full_time  2d_1d              7  freq_200_450, chunks_200
# 20     wideband_full_time   freq              7  freq_200_450, chunks_200
# 21     wideband_long_time  1d_1d              5    freq_0_600, chunks_800
# 22     wideband_long_time  2d_1d              2    freq_0_600, chunks_100
# 23     wideband_long_time   freq              1     freq_0_600, chunks_50
#
#             mean           std          rmse
# 0  -2.208747e-04  2.149061e-03  2.160026e-03
# 1  -9.476961e-05  2.176613e-03  2.178313e-03
# 2  -1.000000e+00  0.000000e+00  1.000000e+00
# 3  -2.678788e-05  8.704125e-04  8.708095e-04
# 4  -2.622490e-05  8.703737e-04  8.707536e-04
# 5  -2.662194e-05  8.704567e-04  8.708486e-04
# 6  -1.874534e-03  5.095745e-03  5.429008e-03
# 7  -1.710447e-04  1.505355e-03  1.514858e-03
# 8  -1.732471e-04  1.506298e-03  1.516045e-03
# 9   1.030271e-04  4.256840e-04  4.374568e-04
# 10  1.132943e-04  4.258121e-04  4.401117e-04
# 11  1.134124e-04  4.260657e-04  4.403868e-04
# 12  1.563033e-17  4.829074e-17  4.959539e-17
# 13  1.563033e-17  4.829074e-17  4.959539e-17
# 14  1.563033e-17  4.829074e-17  4.959539e-17
# 15 -3.324148e-06  1.799921e-03  1.799386e-03
# 16 -5.559090e-05  1.856149e-03  1.856427e-03
# 17 -1.086820e-01  1.589428e-01  1.925084e-01
# 18 -9.771926e-02  1.493424e-01  1.784716e-01
# 19 -7.860602e-02  1.473880e-01  1.670390e-01
# 20 -1.042032e-01  1.581936e-01  1.894292e-01
# 21 -5.149158e-03  4.269675e-02  4.300318e-02
# 22 -2.812065e-04  5.716048e-03  5.722565e-03
# 23  2.679265e-04  4.020263e-03  4.028903e-03
#     baseline                 flag method  config_number  \
# 0     (0, 1)  fullband_short_time  1d_1d              1
# 1     (0, 1)  fullband_short_time  1d_1d              2
# 2     (0, 1)  fullband_short_time  1d_1d              4
# 3     (0, 1)  fullband_short_time  1d_1d              5
# 4     (0, 1)  fullband_short_time  1d_1d              3
# ..       ...                  ...    ...            ...
# 571   (0, 5)   wideband_long_time   freq              5
# 572   (0, 5)   wideband_long_time   freq              1
# 573   (0, 5)   wideband_long_time   freq              2
# 574   (0, 5)   wideband_long_time   freq              6
# 575   (0, 5)   wideband_long_time   freq              7
#
#                 configuration  freq_start  freq_stop  Ntime_chunks      N  \
# 0       freq_0_600, chunks_50           0        600            50  12000
# 1      freq_0_600, chunks_100           0        600           100  12000
# 2      freq_0_600, chunks_400           0        600           400  12000
# 3      freq_0_600, chunks_800           0        600           800  12000
# 4      freq_0_600, chunks_200           0        600           200  12000
# ..                        ...         ...        ...           ...    ...
# 571    freq_0_600, chunks_800           0        600           800   7200
# 572     freq_0_600, chunks_50           0        600            50   7200
# 573    freq_0_600, chunks_100           0        600           100   7200
# 574  freq_150_500, chunks_200         150        500           200   6600
# 575  freq_200_450, chunks_200         200        450           200   6600
#
#          mean       std      rmse  overall_rank
# 0   -0.000141  0.001254  0.001262           1.0
# 1   -0.000220  0.001686  0.001700           2.0
# 2   -0.000071  0.001838  0.001840           3.0
# 3   -0.000073  0.001911  0.001912           4.0
# 4   -0.000209  0.001926  0.001938           5.0
# ..        ...       ...       ...           ...
# 571 -0.001081  0.005057  0.005171           2.0
# 572 -0.001081  0.005057  0.005171           5.0
# 573 -0.001081  0.005057  0.005171           5.0
# 574  0.002619  0.015987  0.016199           7.0
# 575 -0.004208  0.028785  0.029089           8.0
#
# [576 rows x 13 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import numpy as np
import pandas as pd
import torch
from pathlib import Path

import sys
sys.path.append("./")

from utils_load import load_hist_residual


# ============================================================
# Settings
# ============================================================

torch.set_default_dtype(torch.float64)

time_ints = range(80, 1680)
polsi = "ee"
add_real_flags = False

blall = [
    #(0, 1),
     (0, 5),
    # (0, 10),
]

inpaint_method_all = ["2d_1d", "1d_1d", "freq"]

flag_types_all = [
    "narrowband_full_time",
    "wideband_full_time",
    "ultraband_short_time",
    "fullband_short_time",
    "narrowband_short_time",
    "narrowband_long_time",
    "wideband_long_time",
    "randn",
]


# ============================================================
# Frequency and time-chunk configurations
# ============================================================

configurations = [
    {"label": "freq_0_600, chunks_50", "freq_chans": range(0, 600), "Ntime_chunks": 50},
    {"label": "freq_0_600, chunks_100", "freq_chans": range(0, 600), "Ntime_chunks": 100},
    {"label": "freq_0_600, chunks_200", "freq_chans": range(0, 600), "Ntime_chunks": 200},
    {"label": "freq_0_600, chunks_400", "freq_chans": range(0, 600), "Ntime_chunks": 400},
    {"label": "freq_0_600, chunks_800", "freq_chans": range(0, 600), "Ntime_chunks": 800},
    {"label": "freq_150_500, chunks_200", "freq_chans": range(150, 500), "Ntime_chunks": 200},
    {"label": "freq_200_450, chunks_200", "freq_chans": range(200, 450), "Ntime_chunks": 200},
    {"label": "freq_250_400, chunks_200", "freq_chans": range(250, 400), "Ntime_chunks": 200},
]


# ============================================================
# Plot settings
# ============================================================

root_dir = "hist_residual"

hist_bins = 80
hist_quantile = 0.995
display_fraction_x = 0.8

save_figures = True
save_tables = True

figure_dir = Path("hist_comparison_figures")
table_dir = Path("hist_comparison_tables")

figure_dir.mkdir(parents=True, exist_ok=True)
table_dir.mkdir(parents=True, exist_ok=True)

linestyles = [
    "-",
    "--",
    "-.",
    ":",
    (0, (5, 1)),
    (0, (3, 1, 1, 1)),
    (0, (1, 1)),
    (0, (5, 2, 1, 2)),
]


# ============================================================
# Helper functions
# ============================================================

def get_flag_title(flag_typesi, add_real_flags):
    if flag_typesi is None:
        return "Real Flags" if add_real_flags else "No Flags"

    title = flag_typesi.replace("_", " ").title()
    return f"Real Flags + {title}" if add_real_flags else title


def clean_hist_values(hist_residual):
    values = hist_residual.detach().cpu().reshape(-1).numpy()
    return values[np.isfinite(values)]


def calculate_statistics(values):
    if values.size == 0:
        return np.nan, np.nan, np.nan, 0

    mean = np.mean(values)
    std = np.std(values, ddof=1) if values.size > 1 else 0.0
    rmse = np.sqrt(np.mean(values**2))

    return mean, std, rmse, values.size


# ============================================================
# Main loop
# ============================================================

all_statistics = []

for bl in blall:

    # Each flag uses three rows:
    # row 1: histogram
    # row 2: RMSE versus chunks
    # row 3: RMSE versus frequency
    nrows = len(flag_types_all) * 3
    ncols = len(inpaint_method_all)

    fig, axes = plt.subplots(
        nrows,
        ncols,
        figsize=(4.8 * ncols, 2.8 * nrows),
        squeeze=False,
    )

    baseline_statistics = []

    for flag_idx, flag_typesi in enumerate(flag_types_all):

        flag_title = get_flag_title(flag_typesi, add_real_flags)
        flag_results = {}

        hist_row = flag_idx * 3
        chunk_row = hist_row + 1
        freq_row = hist_row + 2

        # ========================================================
        # Load all configurations for this flag
        # ========================================================

        for inpaint_methodi in inpaint_method_all:

            flag_results[inpaint_methodi] = []

            for config_idx, config in enumerate(configurations):

                hist_residual = load_hist_residual(
                    bl=bl, flag_typesi=flag_typesi, add_real_flags=add_real_flags,
                    inpaint_method=inpaint_methodi, freq_chans=config["freq_chans"],
                    time_ints=time_ints, polsi=polsi, Ntime_chunks=config["Ntime_chunks"],
                    root_dir=root_dir, device="cpu",
                )

                values = clean_hist_values(hist_residual)
                mean, std, rmse, sample_number = calculate_statistics(values)

                result = {
                    "config_idx": config_idx,
                    "label": config["label"],
                    "freq_start": config["freq_chans"].start,
                    "freq_stop": config["freq_chans"].stop,
                    "Ntime_chunks": config["Ntime_chunks"],
                    "values": values,
                    "mean": mean,
                    "std": std,
                    "rmse": rmse,
                    "N": sample_number,
                }

                flag_results[inpaint_methodi].append(result)

                baseline_statistics.append({
                    "baseline": str(bl),
                    "polarization": polsi,
                    "flag": flag_typesi,
                    "method": inpaint_methodi,
                    "config_number": config_idx + 1,
                    "configuration": config["label"],
                    "freq_start": config["freq_chans"].start,
                    "freq_stop": config["freq_chans"].stop,
                    "Ntime_chunks": config["Ntime_chunks"],
                    "N": sample_number,
                    "mean": mean,
                    "std": std,
                    "rmse": rmse,
                })

        # ========================================================
        # Plot each algorithm column
        # ========================================================

        for method_idx, inpaint_methodi in enumerate(inpaint_method_all):

            subplot_results = flag_results[inpaint_methodi]

            # ====================================================
            # Row 1: Histogram
            # ====================================================

            ax_hist = axes[hist_row, method_idx]

            valid_arrays = [
                result["values"]
                for result in subplot_results
                if result["values"].size > 0
            ]

            if valid_arrays:

                hist_all = np.concatenate(valid_arrays)
                hist_limit = np.quantile(np.abs(hist_all), hist_quantile)

                if not np.isfinite(hist_limit) or hist_limit <= 0:
                    hist_limit = np.max(np.abs(hist_all))

                if not np.isfinite(hist_limit) or hist_limit <= 0:
                    hist_limit = 1.0

                x_limit = hist_limit * display_fraction_x

                for result in subplot_results:

                    if result["values"].size == 0:
                        continue

                    config_idx = result["config_idx"]

                    ax_hist.hist(
                        result["values"],
                        bins=hist_bins,
                        range=(-hist_limit, hist_limit),
                        density=True,
                        histtype="step",
                        linewidth=1.8,
                        linestyle=linestyles[config_idx % len(linestyles)],
                        label=str(config_idx + 1),
                        zorder=config_idx + 1,
                    )

                ax_hist.axvline(0, color="k", linestyle="--", linewidth=0.8)
                ax_hist.set_xlim(-x_limit, x_limit)
                ax_hist.set_yscale("log")

                ax_hist.legend(
                    fontsize=6,
                    loc="upper right",
                    frameon=True,
                    handlelength=2.0,
                    labelspacing=0.2,
                    borderpad=0.3,
                    ncol=2,
                )

            else:

                ax_hist.text(
                    0.5,
                    0.5,
                    "No data",
                    ha="center",
                    va="center",
                    transform=ax_hist.transAxes,
                )

            ax_hist.tick_params(axis="both", labelsize=8)
            ax_hist.set_ylabel(f"{flag_title}\nDensity" if method_idx == 0 else "Density", fontsize=9)

            if flag_idx == 0:
                ax_hist.set_title(inpaint_methodi, fontsize=13, fontweight="bold")

            ax_hist.set_xlabel(
                r"$(|V_{\mathrm{inp}}|-|V_{\mathrm{true}}|)/|V_{\mathrm{true}}|$",
                fontsize=9,
            )

            # ====================================================
            # Row 2: RMSE versus chunks
            # Only frequency range 0–600
            # ====================================================

            ax_chunk = axes[chunk_row, method_idx]

            chunk_results = [
                result for result in subplot_results
                if result["freq_start"] == 0 and result["freq_stop"] == 600
            ]

            chunk_results = sorted(chunk_results, key=lambda result: result["Ntime_chunks"])

            chunk_x = [result["Ntime_chunks"] for result in chunk_results]
            chunk_rmse = [result["rmse"] for result in chunk_results]

            ax_chunk.plot(
                chunk_x,
                chunk_rmse,
                marker="o",
                linewidth=1.6,
                markersize=5,
            )

            ax_chunk.set_xscale("log", base=2)
            ax_chunk.set_yscale("log")

            ax_chunk.set_xticks([50, 100, 200, 400, 800])
            ax_chunk.set_xticklabels(["50", "100", "200", "400", "800"])

            ax_chunk.set_xlabel("Ntime chunks", fontsize=9)
            ax_chunk.set_ylabel("RMSE", fontsize=9)

            ax_chunk.tick_params(axis="both", labelsize=8)
            ax_chunk.grid(True, which="both", alpha=0.25)

            ax_chunk.set_title(
                "RMSE vs Chunks, Freq 0–600",
                fontsize=9,
            )

            # ====================================================
            # Row 3: RMSE versus frequency range
            # Only Ntime_chunks = 200
            # ====================================================

            ax_freq = axes[freq_row, method_idx]

            freq_configs = [
                (0, 600),
                (150, 500),
                (200, 450),
                (250, 400),
            ]

            freq_positions = np.arange(len(freq_configs))
            freq_labels = [f"{start}–{stop}" for start, stop in freq_configs]

            freq_rmse = []

            for freq_start, freq_stop in freq_configs:

                matching_results = [
                    result for result in subplot_results
                    if result["freq_start"] == freq_start
                    and result["freq_stop"] == freq_stop
                    and result["Ntime_chunks"] == 200
                ]

                if matching_results:
                    freq_rmse.append(matching_results[0]["rmse"])
                else:
                    freq_rmse.append(np.nan)

            ax_freq.plot(
                freq_positions,
                freq_rmse,
                marker="o",
                linewidth=1.6,
                markersize=5,
            )

            ax_freq.set_yscale("log")

            ax_freq.set_xticks(freq_positions)
            ax_freq.set_xticklabels(freq_labels, rotation=25, ha="right")

            ax_freq.set_xlabel("Frequency channels", fontsize=9)
            ax_freq.set_ylabel("RMSE", fontsize=9)

            ax_freq.tick_params(axis="both", labelsize=8)
            ax_freq.grid(True, which="both", alpha=0.25)

            ax_freq.set_title(
                "RMSE vs Frequency, Chunks 200",
                fontsize=9,
            )

    # ========================================================
    # Configuration legend outside the subplots
    # ========================================================

    configuration_handles = [
        Line2D(
            [0],
            [0],
            color="black",
            linewidth=1.8,
            linestyle=linestyles[i % len(linestyles)],
            label=f"{i + 1}: {config['label']}",
        )
        for i, config in enumerate(configurations)
    ]

    fig.legend(
        handles=configuration_handles,
        loc="upper center",
        bbox_to_anchor=(0.5, 0.975),
        ncol=4,
        fontsize=8,
        frameon=True,
        handlelength=2.5,
        columnspacing=1.5,
    )

    fig.suptitle(
        f"Baseline {bl}, Pol {polsi}",
        fontsize=16,
        y=0.998,
    )

    fig.subplots_adjust(
        top=0.93,
        bottom=0.03,
        left=0.08,
        right=0.98,
        hspace=0.65,
        wspace=0.30,
    )

    if save_figures:

        figure_name = (
            f"hist_rmse_grouped_bl_{bl[0]}_{bl[1]}_"
            f"pol_{polsi}.png"
        )

        fig.savefig(
            figure_dir / figure_name,
            dpi=200,
            bbox_inches="tight",
        )

    plt.show()
    plt.close(fig)

    # ========================================================
    # Statistics table
    # ========================================================

    baseline_df = pd.DataFrame(baseline_statistics)

    baseline_df["rank"] = baseline_df.groupby(
        ["flag", "method"]
    )["rmse"].rank(method="min")

    display_columns = [
        "baseline",
        "flag",
        "method",
        "config_number",
        "configuration",
        "freq_start",
        "freq_stop",
        "Ntime_chunks",
        "N",
        "mean",
        "std",
        "rmse",
        "rank",
    ]

    display(
        baseline_df[display_columns]
        .sort_values(["flag", "method", "rank"])
        .reset_index(drop=True)
    )

    # ========================================================
    # Best configuration for each flag and method
    # ========================================================

    best_configuration_df = (
        baseline_df
        .sort_values("rmse")
        .groupby(["flag", "method"], as_index=False)
        .first()
    )

    print(f"\nBest configurations for baseline {bl}:")

    display(
        best_configuration_df[
            [
                "flag",
                "method",
                "config_number",
                "configuration",
                "mean",
                "std",
                "rmse",
            ]
        ]
    )

    if save_tables:

        baseline_df.to_csv(
            table_dir / f"hist_rmse_statistics_bl_{bl[0]}_{bl[1]}_pol_{polsi}.csv",
            index=False,
        )

        best_configuration_df.to_csv(
            table_dir / f"best_rmse_configurations_bl_{bl[0]}_{bl[1]}_pol_{polsi}.csv",
            index=False,
        )

    all_statistics.append(baseline_df)


# ============================================================
# Combined table
# ============================================================

if all_statistics:

    all_statistics_df = pd.concat(all_statistics, ignore_index=True)

    all_statistics_df["overall_rank"] = all_statistics_df.groupby(
        ["baseline", "flag", "method"]
    )["rmse"].rank(method="min")

    display(
        all_statistics_df[
            [
                "baseline",
                "flag",
                "method",
                "config_number",
                "configuration",
                "freq_start",
                "freq_stop",
                "Ntime_chunks",
                "N",
                "mean",
                "std",
                "rmse",
                "overall_rank",
            ]
        ]
        .sort_values(["baseline", "flag", "method", "overall_rank"])
        .reset_index(drop=True)
    )

    if save_tables:

        all_statistics_df.to_csv(
            table_dir / f"hist_rmse_statistics_all_baselines_pol_{polsi}.csv",
            index=False,
        )
# Out:
#     baseline                 flag method  config_number  \
# 0     (0, 5)  fullband_short_time  1d_1d              2
# 1     (0, 5)  fullband_short_time  1d_1d              1
# 2     (0, 5)  fullband_short_time  1d_1d              8
# 3     (0, 5)  fullband_short_time  1d_1d              7
# 4     (0, 5)  fullband_short_time  1d_1d              6
# ..       ...                  ...    ...            ...
# 187   (0, 5)   wideband_long_time   freq              5
# 188   (0, 5)   wideband_long_time   freq              1
# 189   (0, 5)   wideband_long_time   freq              2
# 190   (0, 5)   wideband_long_time   freq              6
# 191   (0, 5)   wideband_long_time   freq              7
#
#                 configuration  freq_start  freq_stop  Ntime_chunks      N  \
# 0      freq_0_600, chunks_100           0        600           100  12000
# 1       freq_0_600, chunks_50           0        600            50  12000
# 2    freq_250_400, chunks_200         250        400           200   3000
# 3    freq_200_450, chunks_200         200        450           200   5000
# 4    freq_150_500, chunks_200         150        500           200   7000
# ..                        ...         ...        ...           ...    ...
# 187    freq_0_600, chunks_800           0        600           800   7200
# 188     freq_0_600, chunks_50           0        600            50   7200
# 189    freq_0_600, chunks_100           0        600           100   7200
# 190  freq_150_500, chunks_200         150        500           200   6600
# 191  freq_200_450, chunks_200         200        450           200   6600
#
#          mean       std      rmse  rank
# 0   -0.000041  0.001912  0.001912   1.0
# 1   -0.000054  0.001995  0.001995   2.0
# 2   -0.000074  0.002275  0.002276   3.0
# 3   -0.000012  0.002748  0.002747   4.0
# 4    0.000002  0.002849  0.002849   5.0
# ..        ...       ...       ...   ...
# 187 -0.001081  0.005057  0.005171   2.0
# 188 -0.001081  0.005057  0.005171   5.0
# 189 -0.001081  0.005057  0.005171   5.0
# 190  0.002619  0.015987  0.016199   7.0
# 191 -0.004208  0.028785  0.029089   8.0
#
# [192 rows x 13 columns]
# Best configurations for baseline (0, 5):
#                      flag method  config_number             configuration  \
# 0     fullband_short_time  1d_1d              2    freq_0_600, chunks_100
# 1     fullband_short_time  2d_1d              2    freq_0_600, chunks_100
# 2     fullband_short_time   freq              2    freq_0_600, chunks_100
# 3    narrowband_full_time  1d_1d              1     freq_0_600, chunks_50
# 4    narrowband_full_time  2d_1d              4    freq_0_600, chunks_400
# 5    narrowband_full_time   freq              3    freq_0_600, chunks_200
# 6    narrowband_long_time  1d_1d              1     freq_0_600, chunks_50
# 7    narrowband_long_time  2d_1d              7  freq_200_450, chunks_200
# 8    narrowband_long_time   freq              7  freq_200_450, chunks_200
# 9   narrowband_short_time  1d_1d              6  freq_150_500, chunks_200
# 10  narrowband_short_time  2d_1d              6  freq_150_500, chunks_200
# 11  narrowband_short_time   freq              6  freq_150_500, chunks_200
# 12                  randn  1d_1d              7  freq_200_450, chunks_200
# 13                  randn  2d_1d              7  freq_200_450, chunks_200
# 14                  randn   freq              7  freq_200_450, chunks_200
# 15   ultraband_short_time  1d_1d              7  freq_200_450, chunks_200
# 16   ultraband_short_time  2d_1d              7  freq_200_450, chunks_200
# 17   ultraband_short_time   freq              7  freq_200_450, chunks_200
# 18     wideband_full_time  1d_1d              7  freq_200_450, chunks_200
# 19     wideband_full_time  2d_1d              7  freq_200_450, chunks_200
# 20     wideband_full_time   freq              7  freq_200_450, chunks_200
# 21     wideband_long_time  1d_1d              5    freq_0_600, chunks_800
# 22     wideband_long_time  2d_1d              7  freq_200_450, chunks_200
# 23     wideband_long_time   freq              8  freq_250_400, chunks_200
#
#             mean           std          rmse
# 0  -4.065385e-05  1.911909e-03  1.912261e-03
# 1   3.055439e-05  1.678828e-03  1.679037e-03
# 2  -1.000000e+00  0.000000e+00  1.000000e+00
# 3   1.052304e-05  6.473249e-04  6.474004e-04
# 4   1.081777e-05  6.466261e-04  6.467065e-04
# 5   1.035972e-05  6.484176e-04  6.484902e-04
# 6  -1.505156e-03  2.577810e-03  2.984789e-03
# 7  -2.724460e-05  7.465773e-04  7.469819e-04
# 8  -9.941083e-06  7.434611e-04  7.434356e-04
# 9  -1.066367e-04  7.244964e-04  7.314056e-04
# 10 -1.019716e-04  7.325049e-04  7.386611e-04
# 11 -9.851454e-05  7.393580e-04  7.449757e-04
# 12  1.143405e-17  3.519404e-17  3.615836e-17
# 13  1.143405e-17  3.519404e-17  3.615836e-17
# 14  1.143405e-17  3.519404e-17  3.615836e-17
# 15 -4.323900e-05  1.640166e-03  1.640193e-03
# 16  7.520251e-05  1.581587e-03  1.582851e-03
# 17 -8.849026e-03  4.097819e-02  4.190951e-02
# 18 -9.554498e-03  2.437892e-02  2.618431e-02
# 19 -1.600482e-03  1.810616e-02  1.817672e-02
# 20 -9.886953e-03  2.494180e-02  2.682988e-02
# 21 -7.771731e-04  1.013990e-02  1.016894e-02
# 22 -5.805645e-04  2.527666e-03  2.593296e-03
# 23 -4.280616e-04  4.116759e-03  4.138670e-03
#     baseline                 flag method  config_number  \
# 0     (0, 5)  fullband_short_time  1d_1d              2
# 1     (0, 5)  fullband_short_time  1d_1d              1
# 2     (0, 5)  fullband_short_time  1d_1d              8
# 3     (0, 5)  fullband_short_time  1d_1d              7
# 4     (0, 5)  fullband_short_time  1d_1d              6
# ..       ...                  ...    ...            ...
# 187   (0, 5)   wideband_long_time   freq              5
# 188   (0, 5)   wideband_long_time   freq              1
# 189   (0, 5)   wideband_long_time   freq              2
# 190   (0, 5)   wideband_long_time   freq              6
# 191   (0, 5)   wideband_long_time   freq              7
#
#                 configuration  freq_start  freq_stop  Ntime_chunks      N  \
# 0      freq_0_600, chunks_100           0        600           100  12000
# 1       freq_0_600, chunks_50           0        600            50  12000
# 2    freq_250_400, chunks_200         250        400           200   3000
# 3    freq_200_450, chunks_200         200        450           200   5000
# 4    freq_150_500, chunks_200         150        500           200   7000
# ..                        ...         ...        ...           ...    ...
# 187    freq_0_600, chunks_800           0        600           800   7200
# 188     freq_0_600, chunks_50           0        600            50   7200
# 189    freq_0_600, chunks_100           0        600           100   7200
# 190  freq_150_500, chunks_200         150        500           200   6600
# 191  freq_200_450, chunks_200         200        450           200   6600
#
#          mean       std      rmse  overall_rank
# 0   -0.000041  0.001912  0.001912           1.0
# 1   -0.000054  0.001995  0.001995           2.0
# 2   -0.000074  0.002275  0.002276           3.0
# 3   -0.000012  0.002748  0.002747           4.0
# 4    0.000002  0.002849  0.002849           5.0
# ..        ...       ...       ...           ...
# 187 -0.001081  0.005057  0.005171           2.0
# 188 -0.001081  0.005057  0.005171           5.0
# 189 -0.001081  0.005057  0.005171           5.0
# 190  0.002619  0.015987  0.016199           7.0
# 191 -0.004208  0.028785  0.029089           8.0
#
# [192 rows x 13 columns]

# %%
1
# Out:
# 1
