# %%
import numpy as np

# (Nbls, Ntimes, Nfreq, Npol)=(1,1600,600,1)

# EoR only
d_eor = np.load("generate_data/eor_data.npz", allow_pickle=True)
eor_data_raw = d_eor["data"]
freqs_eor = d_eor["freqs"]   # unit MHz
times_eor = d_eor["times"]

# EoR + foreground
d_fg = np.load("generate_data/eor_fg_data.npz", allow_pickle=True)
eor_fg_data_raw = d_fg["data"]

# EoR + foreground + noise
d_efn = np.load("generate_data/eor_fg_noise.npz", allow_pickle=True)
eor_fg_noise_raw = d_efn["data"]

# Thermal noise
d_noise = np.load("generate_data/noise.npz", allow_pickle=True)
noise_raw = d_noise["noise"]
noise_var_raw = d_noise["noise_var"]


# Flags
d_flag = np.load("generate_data/flags.npz", allow_pickle=True)
flags_raw = d_flag["flags"]

# Check original shapes
print("Original shapes")
print("eor_data_raw      :", eor_data_raw.shape)
print("eor_fg_data_raw   :", eor_fg_data_raw.shape)
print("eor_fg_noise_raw  :", eor_fg_noise_raw.shape)
print("noise_raw         :", noise_raw.shape)
print("noise_var_raw     :", noise_var_raw.shape)
print("flags_raw         :", flags_raw.shape)
# Out:
# Original shapes
# eor_data_raw      : (1, 1600, 600, 1)
# eor_fg_data_raw   : (1, 1600, 600, 1)
# eor_fg_noise_raw  : (1, 1600, 600, 1)
# noise_raw         : (1, 1600, 600, 1)
# noise_var_raw     : (1, 1600, 600, 1)
# flags_raw         : (1, 1600, 600, 1)

# %% [markdown]
# # cut part

# %%
# (1, 1600, 600, 1) -> (1, 20, 180, 1)

eor_data_raw      = eor_data_raw[:, :20, :, :]
eor_fg_data_raw   = eor_fg_data_raw[:, :20, :, :]
eor_fg_noise_raw  = eor_fg_noise_raw[:, :20, :, :]
noise_raw         = noise_raw[:, :20, :, :]
noise_var_raw     = noise_var_raw[:, :20, :, :]
flags_raw         = flags_raw[:, :20, :, :]

# 如果频率数组长度是 600，也同步截取
freqs_eor = freqs_eor[:]

# 如果 times_eor 长度是 1600，也同步截取
times_eor = times_eor[:20]

print("\nTrimmed shapes")
print("eor_data_raw      :", eor_data_raw.shape)
print("eor_fg_data_raw   :", eor_fg_data_raw.shape)
print("eor_fg_noise_raw  :", eor_fg_noise_raw.shape)
print("noise_raw         :", noise_raw.shape)
print("noise_var_raw     :", noise_var_raw.shape)
print("flags_raw         :", flags_raw.shape)
# Out:
# Trimmed shapes
# eor_data_raw      : (1, 20, 600, 1)
# eor_fg_data_raw   : (1, 20, 600, 1)
# eor_fg_noise_raw  : (1, 20, 600, 1)
# noise_raw         : (1, 20, 600, 1)
# noise_var_raw     : (1, 20, 600, 1)
# flags_raw         : (1, 20, 600, 1)

# %%
# convert: (Nbls, Ntimes, Nfreq, Npol)
#       -> (Npol, Nbls，Ntimes,  Nfreq)

eor_data     = np.transpose(eor_data_raw,     (3, 0, 1, 2))
eor_fg_data  = np.transpose(eor_fg_data_raw,  (3, 0, 1, 2))
eor_fg_noise = np.transpose(eor_fg_noise_raw, (3, 0, 1, 2))
noise         = np.transpose(noise_raw,        (3, 0, 1, 2))
noise_var     = np.transpose(noise_var_raw,    (3, 0, 1, 2))
flags         = np.transpose(flags_raw,        (3, 0, 1, 2))

# Check converted shapes
print("\nConverted shapes")
print("eor_data      :", eor_data.shape)
print("eor_fg_data   :", eor_fg_data.shape)
print("eor_fg_noise  :", eor_fg_noise.shape)
print("noise         :", noise.shape)
print("noise_var     :", noise_var.shape)
print("flags         :", flags.shape)
# Out:
# Converted shapes
# eor_data      : (1, 1, 20, 600)
# eor_fg_data   : (1, 1, 20, 600)
# eor_fg_noise  : (1, 1, 20, 600)
# noise         : (1, 1, 20, 600)
# noise_var     : (1, 1, 20, 600)
# flags         : (1, 1, 20, 600)

# %%
import numpy as np
from matplotlib import pyplot as plt
#d = np.load("/Users/alliswell48/simpleQE/notebooks/generate_datat/gpr_inpaint_input.npz")

#fchans = [(20, 21), (40, 41), (80, 81), (95, 96), (120, 121),[170,171]]

data0 = eor_fg_noise
inp_flags0 = flags 
inv_wgts0 = noise_var
freqs0 = freqs_eor
fg0=eor_fg_data -eor_data 
noise0=noise



inv_wgts0 = inv_wgts0.copy()
inv_wgts0[inp_flags0] = 2e10     # ≫ outputscale(1e3),又 ≪ 1e10


print(data0.shape)
print(inp_flags0.shape)
print(inv_wgts0.shape)
print(freqs0.shape)
print(fg0.shape)
print(noise0.shape)
# Out:
# (1, 1, 20, 600)
# (1, 1, 20, 600)
# (1, 1, 20, 600)
# (600,)
# (1, 1, 20, 600)
# (1, 1, 20, 600)

# %%
import torch

# numpy → torch
data = torch.tensor(data0)
inp_flags = torch.tensor(inp_flags0)
inv_wgts = torch.tensor(inv_wgts0)
freqs = torch.tensor(freqs0)

# 统一 dtype
freqs = freqs.double()               # Hz, float32
data = data.to(torch.complex128)     # complex64
inv_wgts = inv_wgts.double()         # float32
inp_flags = inp_flags.bool()        # bool

# 检查
print("data.shape =", data.shape)
print("inp_flags.shape =", inp_flags.shape)
print("inv_wgts.shape =", inv_wgts.shape)
print("freqs.shape =", freqs.shape)

print("data.dtype =", data.dtype)
print("inp_flags.dtype =", inp_flags.dtype)
print("inv_wgts.dtype =", inv_wgts.dtype)
print("freqs.dtype =", freqs.dtype)
# Out:
# data.shape = torch.Size([1, 1, 20, 600])
# inp_flags.shape = torch.Size([1, 1, 20, 600])
# inv_wgts.shape = torch.Size([1, 1, 20, 600])
# freqs.shape = torch.Size([600])
# data.dtype = torch.complex128
# inp_flags.dtype = torch.bool
# inv_wgts.dtype = torch.float64
# freqs.dtype = torch.float64

# %%
Nbls, Ntimes, Nfreqs = data.shape[-3:]  #忽律pol 极化维度
train_y = torch.vstack([data.real.reshape(-1, Nfreqs), data.imag.reshape(-1, Nfreqs)])

# %%
# per band, per red-group, per-pol inpainting

data   #(Npol,Nbls, Ntimes, Nfreq)=>(1,1, Ntimes, Nfreq)
inv_wgts
inp_flags
freqs
bl_len = 14.6   # meter,HERA baseline, 现在只假设一个固定基线
kernA_var=0.01
center_y=True
Ndeg=1 #polfit
horizon_buffer=150
min_horizon_dly=150
kernA='sinc'   #最外层
kernB='sinc'  #中层
kernB_buffer=200
kernB_max_dly=1000
kernB_rel_var=0.01
kernC='sinc'    #最内层
kernC_buffer=500
kernC_max_dly=1200
kernC_rel_var=0.1

# %%
Nfreqs
# Out:
# 600

# %%
train_xt = freqs[:, None]  # [MHz] Size([3，1])
#freqs[:]=>freqs[:, None].shape 等价于freqs.Size([3])=>freqs.Size([3，1])

train_x = train_xt.expand((1, Nfreqs, 1)) # Size([3，1]) =>Size([1, 3, 1])
inp_flags = torch.vstack([inp_flags.reshape(-1, Nfreqs), inp_flags.reshape(-1, Nfreqs)])
train_wgts = torch.vstack([inv_wgts.reshape(-1, Nfreqs), inv_wgts.reshape(-1, Nfreqs)]) / 2  # real/imag

# tau [ns] to sinc length-scale [MHz]
tau2ls = lambda tau: 1e3 / 2 / tau  # ns
bl_tau = max([bl_len / 2.99792e8 * 1e9 + horizon_buffer, min_horizon_dly])  # ns

# %%
# get mean and covar model of 3-sinc mixture

import gprlim
from gprlim import models

print(gprlim.__file__)

mean, covar = models.multi_kernel_mixture(
    mean_fix_constant=True,
    mean_set_constant=0,
    kern2=kernA,
    kern2_set_lengthscale=tau2ls(bl_tau),
    kern2_set_outputscale=kernA_var,
    kern1=kernB,
    kern1_set_lengthscale=tau2ls(min([bl_tau + kernB_buffer, kernB_max_dly])),
    kern1_set_outputscale=kernB_rel_var,
    kern0=kernC,
    kern0_set_lengthscale=tau2ls(min([bl_tau + kernC_buffer, kernC_max_dly])),
    kern0_set_outputscale=kernC_rel_var,
)
# Out:
# /Users/alliswell48/gprlim/gprlim/__init__.py

# %%
# get GPModel
model, y_offset = models.fixednoise_gp_1d(
    train_x, train_y, mean, covar, inv_wgts=train_wgts, center_y=center_y, Ndeg=Ndeg,
    
)
y_offset = y_offset if y_offset is not None else 0

# %%
y_offset
# Out:
# tensor([[12.6988, 12.6988, 12.6988,  ..., 12.6988, 12.6988, 12.6988],
#         [12.8557, 12.8557, 12.8557,  ..., 12.8557, 12.8557, 12.8557],
#         [13.1215, 13.1215, 13.1215,  ..., 13.1215, 13.1215, 13.1215],
#         ...,
#         [16.7579, 16.7579, 16.7579,  ..., 16.7579, 16.7579, 16.7579],
#         [16.1763, 16.1763, 16.1763,  ..., 16.1763, 16.1763, 16.1763],
#         [16.0418, 16.0418, 16.0418,  ..., 16.0418, 16.0418, 16.0418]],
#        dtype=torch.float64)

# %%
optimizer = torch.optim.LBFGS(
    model.parameters(),
    lr=0.1,
    #max_iter=1
)

loss, opt = models.optimize_kernel(
    model,
    Niter=30,
    opt=optimizer,
    thresh=None,
    #thresh=1e-5
)
# Out:
# Iter   1/ 30 Loss=  45.843   outputscale=  0.0100   lengthscale=  2.5164   outputscale=  0.0100   lengthscale=  1.2541   outputscale=  0.1000   lengthscale=  0.7156
# Iter   1/ 30 Loss=  45.744   outputscale=  0.0108   lengthscale=  2.5386   outputscale=  0.0100   lengthscale=  1.2542   outputscale=  0.1000   lengthscale=  0.7156
# Iter   1/ 30 Loss=  45.562   outputscale=  0.0122   lengthscale=  2.5763   outputscale=  0.0100   lengthscale=  1.2545   outputscale=  0.1000   lengthscale=  0.7156
# Iter   1/ 30 Loss=  45.326   outputscale=  0.0140   lengthscale=  2.6206   outputscale=  0.0100   lengthscale=  1.2547   outputscale=  0.1000   lengthscale=  0.7157
# Iter   1/ 30 Loss=  45.009   outputscale=  0.0165   lengthscale=  2.6719   outputscale=  0.0100   lengthscale=  1.2551   outputscale=  0.1000   lengthscale=  0.7157
# Iter   1/ 30 Loss=  44.567   outputscale=  0.0199   lengthscale=  2.7326   outputscale=  0.0100   lengthscale=  1.2554   outputscale=  0.1000   lengthscale=  0.7157
# Iter   1/ 30 Loss=  43.922   outputscale=  0.0249   lengthscale=  2.8054   outputscale=  0.0100   lengthscale=  1.2558   outputscale=  0.1000   lengthscale=  0.7157
# Iter   1/ 30 Loss=  42.930   outputscale=  0.0328   lengthscale=  2.8918   outputscale=  0.0101   lengthscale=  1.2564   outputscale=  0.1000   lengthscale=  0.7157
# Iter   1/ 30 Loss=  41.283   outputscale=  0.0467   lengthscale=  3.0026   outputscale=  0.0101   lengthscale=  1.2570   outputscale=  0.1000   lengthscale=  0.7158
# Iter   1/ 30 Loss=  38.395   outputscale=  0.0740   lengthscale=  3.1422   outputscale=  0.0101   lengthscale=  1.2578   outputscale=  0.1001   lengthscale=  0.7158
# Iter   1/ 30 Loss=  33.222   outputscale=  0.1362   lengthscale=  3.3219   outputscale=  0.0101   lengthscale=  1.2589   outputscale=  0.1001   lengthscale=  0.7159
# Iter   1/ 30 Loss=  25.458   outputscale=  0.2879   lengthscale=  3.5555   outputscale=  0.0102   lengthscale=  1.2603   outputscale=  0.1001   lengthscale=  0.7160
# Iter   1/ 30 Loss=  18.269   outputscale=  0.5798   lengthscale=  3.8127   outputscale=  0.0102   lengthscale=  1.2618   outputscale=  0.1001   lengthscale=  0.7160
# Iter   1/ 30 Loss=  16.443   outputscale=  0.7089   lengthscale=  3.8953   outputscale=  0.0102   lengthscale=  1.2624   outputscale=  0.1001   lengthscale=  0.7161
# Iter   1/ 30 Loss=  15.239   outputscale=  0.8101   lengthscale=  3.9898   outputscale=  0.0102   lengthscale=  1.2630   outputscale=  0.1001   lengthscale=  0.7161
# Iter   1/ 30 Loss=  14.168   outputscale=  0.9114   lengthscale=  4.1204   outputscale=  0.0103   lengthscale=  1.2637   outputscale=  0.1001   lengthscale=  0.7162
# Iter   1/ 30 Loss=  13.421   outputscale=  1.0007   lengthscale=  4.2009   outputscale=  0.0103   lengthscale=  1.2643   outputscale=  0.1001   lengthscale=  0.7162
# Iter   1/ 30 Loss=  12.766   outputscale=  1.0970   lengthscale=  4.2533   outputscale=  0.0103   lengthscale=  1.2650   outputscale=  0.1002   lengthscale=  0.7162
# Iter   1/ 30 Loss=  12.165   outputscale=  1.1997   lengthscale=  4.3038   outputscale=  0.0103   lengthscale=  1.2658   outputscale=  0.1002   lengthscale=  0.7163
# Iter   1/ 30 Loss=  11.614   outputscale=  1.3057   lengthscale=  4.3640   outputscale=  0.0104   lengthscale=  1.2668   outputscale=  0.1002   lengthscale=  0.7164
# Iter   2/ 30 Loss=  11.081   outputscale=  1.4167   lengthscale=  4.4509   outputscale=  0.0104   lengthscale=  1.2680   outputscale=  0.1002   lengthscale=  0.7164
# Iter   2/ 30 Loss=  10.493   outputscale=  1.5432   lengthscale=  4.5999   outputscale=  0.0105   lengthscale=  1.2696   outputscale=  0.1002   lengthscale=  0.7165
# Iter   2/ 30 Loss=  10.014   outputscale=  1.6572   lengthscale=  4.7624   outputscale=  0.0105   lengthscale=  1.2712   outputscale=  0.1003   lengthscale=  0.7166
# Iter   2/ 30 Loss=   9.739   outputscale=  1.7438   lengthscale=  4.8305   outputscale=  0.0106   lengthscale=  1.2724   outputscale=  0.1003   lengthscale=  0.7167
# Iter   2/ 30 Loss=   9.447   outputscale=  1.8534   lengthscale=  4.8846   outputscale=  0.0106   lengthscale=  1.2740   outputscale=  0.1003   lengthscale=  0.7168
# Iter   2/ 30 Loss=   9.162   outputscale=  1.9755   lengthscale=  4.9321   outputscale=  0.0107   lengthscale=  1.2760   outputscale=  0.1003   lengthscale=  0.7170
# Iter   2/ 30 Loss=   8.895   outputscale=  2.1043   lengthscale=  4.9782   outputscale=  0.0107   lengthscale=  1.2784   outputscale=  0.1004   lengthscale=  0.7171
# Iter   2/ 30 Loss=   8.646   outputscale=  2.2385   lengthscale=  5.0261   outputscale=  0.0108   lengthscale=  1.2814   outputscale=  0.1004   lengthscale=  0.7173
# Iter   2/ 30 Loss=   8.413   outputscale=  2.3773   lengthscale=  5.0777   outputscale=  0.0109   lengthscale=  1.2850   outputscale=  0.1005   lengthscale=  0.7175
# Iter   2/ 30 Loss=   8.198   outputscale=  2.5199   lengthscale=  5.1330   outputscale=  0.0111   lengthscale=  1.2891   outputscale=  0.1005   lengthscale=  0.7177
# Iter   2/ 30 Loss=   8.002   outputscale=  2.6652   lengthscale=  5.1873   outputscale=  0.0112   lengthscale=  1.2937   outputscale=  0.1006   lengthscale=  0.7180
# Iter   2/ 30 Loss=   7.825   outputscale=  2.8134   lengthscale=  5.2318   outputscale=  0.0114   lengthscale=  1.2984   outputscale=  0.1007   lengthscale=  0.7183
# Iter   2/ 30 Loss=   7.662   outputscale=  2.9701   lengthscale=  5.2602   outputscale=  0.0116   lengthscale=  1.3033   outputscale=  0.1008   lengthscale=  0.7187
# Iter   2/ 30 Loss=   7.504   outputscale=  3.1406   lengthscale=  5.2729   outputscale=  0.0119   lengthscale=  1.3085   outputscale=  0.1009   lengthscale=  0.7191
# Iter   2/ 30 Loss=   7.354   outputscale=  3.3230   lengthscale=  5.2756   outputscale=  0.0122   lengthscale=  1.3145   outputscale=  0.1010   lengthscale=  0.7196
# Iter   2/ 30 Loss=   7.212   outputscale=  3.5142   lengthscale=  5.2747   outputscale=  0.0126   lengthscale=  1.3226   outputscale=  0.1012   lengthscale=  0.7202
# Iter   2/ 30 Loss=   7.077   outputscale=  3.7141   lengthscale=  5.2729   outputscale=  0.0130   lengthscale=  1.3348   outputscale=  0.1014   lengthscale=  0.7209
# Iter   2/ 30 Loss=   6.949   outputscale=  3.9228   lengthscale=  5.2707   outputscale=  0.0136   lengthscale=  1.3510   outputscale=  0.1016   lengthscale=  0.7217
# Iter   2/ 30 Loss=   6.828   outputscale=  4.1403   lengthscale=  5.2681   outputscale=  0.0144   lengthscale=  1.3644   outputscale=  0.1019   lengthscale=  0.7227
# Iter   2/ 30 Loss=   6.712   outputscale=  4.3688   lengthscale=  5.2653   outputscale=  0.0154   lengthscale=  1.3823   outputscale=  0.1022   lengthscale=  0.7238
# Iter   3/ 30 Loss=   6.600   outputscale=  4.6112   lengthscale=  5.2626   outputscale=  0.0167   lengthscale=  1.4157   outputscale=  0.1027   lengthscale=  0.7252
# Iter   3/ 30 Loss=   6.494   outputscale=  4.8615   lengthscale=  5.2605   outputscale=  0.0185   lengthscale=  1.4412   outputscale=  0.1032   lengthscale=  0.7267
# Iter   3/ 30 Loss=   6.387   outputscale=  5.1384   lengthscale=  5.2587   outputscale=  0.0212   lengthscale=  1.4976   outputscale=  0.1039   lengthscale=  0.7287
# Iter   3/ 30 Loss=   6.283   outputscale=  5.4276   lengthscale=  5.2599   outputscale=  0.0253   lengthscale=  1.5616   outputscale=  0.1048   lengthscale=  0.7310
# Iter   3/ 30 Loss=   6.173   outputscale=  5.7574   lengthscale=  5.2637   outputscale=  0.0326   lengthscale=  1.6524   outputscale=  0.1061   lengthscale=  0.7342
# Iter   3/ 30 Loss=   6.039   outputscale=  6.1752   lengthscale=  5.2758   outputscale=  0.0490   lengthscale=  1.7976   outputscale=  0.1082   lengthscale=  0.7397
# Iter   3/ 30 Loss=   5.777   outputscale=  6.9908   lengthscale=  5.3148   outputscale=  0.1239   lengthscale=  2.1426   outputscale=  0.1132   lengthscale=  0.7545
# Iter   3/ 30 Loss=   5.489   outputscale=  7.8280   lengthscale=  5.3570   outputscale=  0.3094   lengthscale=  2.5233   outputscale=  0.1186   lengthscale=  0.7702
# Iter   3/ 30 Loss=   5.181   outputscale=  8.6793   lengthscale=  5.3999   outputscale=  0.7130   lengthscale=  2.9127   outputscale=  0.1245   lengthscale=  0.7870
# Iter   3/ 30 Loss=   4.910   outputscale=  9.5412   lengthscale=  5.4416   outputscale=  1.3980   lengthscale=  3.3394   outputscale=  0.1307   lengthscale=  0.8049
# Iter   3/ 30 Loss=   4.845   outputscale=  9.7669   lengthscale=  5.4437   outputscale=  1.6444   lengthscale=  3.4873   outputscale=  0.1273   lengthscale=  0.8342
# Iter   3/ 30 Loss=   4.798   outputscale=  9.9618   lengthscale=  5.4407   outputscale=  1.8652   lengthscale=  3.6401   outputscale=  0.1210   lengthscale=  0.9228
# Iter   3/ 30 Loss=   4.765   outputscale= 10.1067   lengthscale=  5.4397   outputscale=  2.0675   lengthscale=  3.6516   outputscale=  0.1165   lengthscale=  0.9872
# Iter   3/ 30 Loss=   4.724   outputscale= 10.3069   lengthscale=  5.4378   outputscale=  2.3331   lengthscale=  3.7185   outputscale=  0.1104   lengthscale=  1.1369
# Iter   3/ 30 Loss=   4.614   outputscale= 10.9372   lengthscale=  5.4292   outputscale=  3.1640   lengthscale=  4.0770   outputscale=  0.0942   lengthscale=  1.7464
# Iter   3/ 30 Loss=   4.594   outputscale= 11.0827   lengthscale=  5.4250   outputscale=  3.3549   lengthscale=  4.1597   outputscale=  0.0940   lengthscale=  1.9114
# Iter   3/ 30 Loss=   4.567   outputscale= 11.3013   lengthscale=  5.4177   outputscale=  3.6260   lengthscale=  4.3438   outputscale=  0.0961   lengthscale=  2.0659
# Iter   3/ 30 Loss=   4.549   outputscale= 11.4659   lengthscale=  5.4074   outputscale=  3.8242   lengthscale=  4.4926   outputscale=  0.0983   lengthscale=  2.1662
# Iter   3/ 30 Loss=   4.538   outputscale= 11.5824   lengthscale=  5.4006   outputscale=  3.9691   lengthscale=  4.5759   outputscale=  0.1002   lengthscale=  2.2648
# Iter   3/ 30 Loss=   4.525   outputscale= 11.7273   lengthscale=  5.3924   outputscale=  4.1469   lengthscale=  4.6876   outputscale=  0.1046   lengthscale=  2.3355
# Iter   4/ 30 Loss=   4.480   outputscale= 12.3660   lengthscale=  5.3549   outputscale=  4.9186   lengthscale=  5.2203   outputscale=  0.1283   lengthscale=  2.6956
# Iter   4/ 30 Loss=   4.474   outputscale= 12.4793   lengthscale=  5.3465   outputscale=  5.0570   lengthscale=  5.2978   outputscale=  0.1365   lengthscale=  2.7796
# Iter   4/ 30 Loss=   4.470   outputscale= 12.5676   lengthscale=  5.3370   outputscale=  5.1636   lengthscale=  5.3588   outputscale=  0.1450   lengthscale=  2.8141
# Iter   4/ 30 Loss=   4.452   outputscale= 12.9593   lengthscale=  5.2784   outputscale=  5.6374   lengthscale=  5.6058   outputscale=  0.1954   lengthscale=  3.0120
# Iter   4/ 30 Loss=   4.428   outputscale= 13.5360   lengthscale=  5.1831   outputscale=  6.3375   lengthscale=  5.9459   outputscale=  0.3066   lengthscale=  3.3545
# Iter   4/ 30 Loss=   4.406   outputscale= 14.0718   lengthscale=  5.1153   outputscale=  6.9862   lengthscale=  6.2748   outputscale=  0.4925   lengthscale=  3.6716
# Iter   4/ 30 Loss=   4.399   outputscale= 14.2958   lengthscale=  5.0865   outputscale=  7.2552   lengthscale=  6.4184   outputscale=  0.6056   lengthscale=  3.7881
# Iter   4/ 30 Loss=   4.397   outputscale= 14.3875   lengthscale=  5.0716   outputscale=  7.3646   lengthscale=  6.4758   outputscale=  0.6661   lengthscale=  3.8220
# Iter   4/ 30 Loss=   4.391   outputscale= 14.5844   lengthscale=  5.0429   outputscale=  7.6002   lengthscale=  6.5985   outputscale=  0.8111   lengthscale=  3.9037
# Iter   4/ 30 Loss=   4.362   outputscale= 15.9159   lengthscale=  4.8525   outputscale=  9.1977   lengthscale=  7.4259   outputscale=  2.1860   lengthscale=  4.5258
# Iter   4/ 30 Loss=   4.360   outputscale= 16.0566   lengthscale=  4.8346   outputscale=  9.3667   lengthscale=  7.5147   outputscale=  2.3540   lengthscale=  4.5948
# Iter   4/ 30 Loss=   4.352   outputscale= 16.6475   lengthscale=  4.7603   outputscale= 10.0764   lengthscale=  7.8892   outputscale=  3.0741   lengthscale=  4.8936
# Iter   4/ 30 Loss=   4.351   outputscale= 16.8170   lengthscale=  4.8052   outputscale= 10.2888   lengthscale=  8.0017   outputscale=  3.2915   lengthscale=  4.9893
# Iter   4/ 30 Loss=   4.349   outputscale= 16.9670   lengthscale=  4.8738   outputscale= 10.4807   lengthscale=  8.1030   outputscale=  3.4915   lengthscale=  5.0787
# Iter   4/ 30 Loss=   4.346   outputscale= 17.2015   lengthscale=  5.0008   outputscale= 10.7832   lengthscale=  8.2698   outputscale=  3.7807   lengthscale=  5.2207
# Iter   4/ 30 Loss=   4.344   outputscale= 17.5117   lengthscale=  5.2039   outputscale= 11.1878   lengthscale=  8.5059   outputscale=  4.1229   lengthscale=  5.4121
# Iter   4/ 30 Loss=   4.344   outputscale= 17.5362   lengthscale=  5.2209   outputscale= 11.2198   lengthscale=  8.5249   outputscale=  4.1492   lengthscale=  5.4273
# Iter   4/ 30 Loss=   4.344   outputscale= 17.5444   lengthscale=  5.2263   outputscale= 11.2306   lengthscale=  8.5314   outputscale=  4.1578   lengthscale=  5.4323
# Iter   4/ 30 Loss=   4.344   outputscale= 17.5516   lengthscale=  5.2308   outputscale= 11.2398   lengthscale=  8.5370   outputscale=  4.1648   lengthscale=  5.4365
# Iter   4/ 30 Loss=   4.344   outputscale= 17.5580   lengthscale=  5.2345   outputscale= 11.2481   lengthscale=  8.5422   outputscale=  4.1709   lengthscale=  5.4402
# Iter   5/ 30 Loss=   4.344   outputscale= 17.5639   lengthscale=  5.2377   outputscale= 11.2557   lengthscale=  8.5471   outputscale=  4.1761   lengthscale=  5.4434
# Iter   5/ 30 Loss=   4.344   outputscale= 17.5694   lengthscale=  5.2405   outputscale= 11.2626   lengthscale=  8.5516   outputscale=  4.1807   lengthscale=  5.4463
# Iter   5/ 30 Loss=   4.344   outputscale= 17.5745   lengthscale=  5.2428   outputscale= 11.2691   lengthscale=  8.5560   outputscale=  4.1847   lengthscale=  5.4489
# Iter   5/ 30 Loss=   4.344   outputscale= 17.5793   lengthscale=  5.2447   outputscale= 11.2751   lengthscale=  8.5601   outputscale=  4.1882   lengthscale=  5.4513
# Iter   5/ 30 Loss=   4.344   outputscale= 17.5840   lengthscale=  5.2464   outputscale= 11.2808   lengthscale=  8.5642   outputscale=  4.1912   lengthscale=  5.4534
# Iter   5/ 30 Loss=   4.344   outputscale= 17.5884   lengthscale=  5.2478   outputscale= 11.2863   lengthscale=  8.5681   outputscale=  4.1939   lengthscale=  5.4554
# Iter   5/ 30 Loss=   4.344   outputscale= 17.5927   lengthscale=  5.2490   outputscale= 11.2916   lengthscale=  8.5720   outputscale=  4.1963   lengthscale=  5.4572
# Iter   5/ 30 Loss=   4.344   outputscale= 17.5970   lengthscale=  5.2500   outputscale= 11.2968   lengthscale=  8.5760   outputscale=  4.1984   lengthscale=  5.4589
# Iter   5/ 30 Loss=   4.344   outputscale= 17.6013   lengthscale=  5.2508   outputscale= 11.3019   lengthscale=  8.5800   outputscale=  4.2003   lengthscale=  5.4605
# Iter   5/ 30 Loss=   4.344   outputscale= 17.6056   lengthscale=  5.2514   outputscale= 11.3071   lengthscale=  8.5840   outputscale=  4.2019   lengthscale=  5.4621
# Iter   5/ 30 Loss=   4.344   outputscale= 17.6100   lengthscale=  5.2518   outputscale= 11.3123   lengthscale=  8.5883   outputscale=  4.2033   lengthscale=  5.4636
# Iter   5/ 30 Loss=   4.344   outputscale= 17.6145   lengthscale=  5.2521   outputscale= 11.3177   lengthscale=  8.5927   outputscale=  4.2046   lengthscale=  5.4650
# Iter   5/ 30 Loss=   4.344   outputscale= 17.6194   lengthscale=  5.2522   outputscale= 11.3233   lengthscale=  8.5975   outputscale=  4.2057   lengthscale=  5.4665
# Iter   5/ 30 Loss=   4.344   outputscale= 17.6245   lengthscale=  5.2521   outputscale= 11.3293   lengthscale=  8.6026   outputscale=  4.2066   lengthscale=  5.4680
# Iter   5/ 30 Loss=   4.344   outputscale= 17.6301   lengthscale=  5.2518   outputscale= 11.3357   lengthscale=  8.6083   outputscale=  4.2074   lengthscale=  5.4695
# Iter   5/ 30 Loss=   4.344   outputscale= 17.6362   lengthscale=  5.2513   outputscale= 11.3428   lengthscale=  8.6145   outputscale=  4.2079   lengthscale=  5.4710
# Iter   5/ 30 Loss=   4.344   outputscale= 17.6430   lengthscale=  5.2505   outputscale= 11.3506   lengthscale=  8.6215   outputscale=  4.2083   lengthscale=  5.4727
# Iter   5/ 30 Loss=   4.344   outputscale= 17.6508   lengthscale=  5.2494   outputscale= 11.3594   lengthscale=  8.6296   outputscale=  4.2085   lengthscale=  5.4744
# Iter   5/ 30 Loss=   4.344   outputscale= 17.6596   lengthscale=  5.2478   outputscale= 11.3694   lengthscale=  8.6388   outputscale=  4.2083   lengthscale=  5.4763
# Iter   5/ 30 Loss=   4.344   outputscale= 17.6699   lengthscale=  5.2457   outputscale= 11.3810   lengthscale=  8.6497   outputscale=  4.2079   lengthscale=  5.4784
# Iter   6/ 30 Loss=   4.344   outputscale= 17.6821   lengthscale=  5.2428   outputscale= 11.3946   lengthscale=  8.6625   outputscale=  4.2071   lengthscale=  5.4808
# Iter   6/ 30 Loss=   4.344   outputscale= 17.6967   lengthscale=  5.2391   outputscale= 11.4110   lengthscale=  8.6781   outputscale=  4.2057   lengthscale=  5.4836
# Iter   6/ 30 Loss=   4.344   outputscale= 17.7147   lengthscale=  5.2340   outputscale= 11.4310   lengthscale=  8.6972   outputscale=  4.2037   lengthscale=  5.4868
# Iter   6/ 30 Loss=   4.344   outputscale= 17.7372   lengthscale=  5.2271   outputscale= 11.4559   lengthscale=  8.7213   outputscale=  4.2008   lengthscale=  5.4908
# Iter   6/ 30 Loss=   4.344   outputscale= 17.7660   lengthscale=  5.2177   outputscale= 11.4878   lengthscale=  8.7521   outputscale=  4.1967   lengthscale=  5.4957
# Iter   6/ 30 Loss=   4.344   outputscale= 17.8025   lengthscale=  5.2053   outputscale= 11.5281   lengthscale=  8.7913   outputscale=  4.1910   lengthscale=  5.5019
# Iter   6/ 30 Loss=   4.344   outputscale= 17.8441   lengthscale=  5.1907   outputscale= 11.5739   lengthscale=  8.8361   outputscale=  4.1835   lengthscale=  5.5087
# Iter   6/ 30 Loss=   4.344   outputscale= 17.8815   lengthscale=  5.1779   outputscale= 11.6149   lengthscale=  8.8767   outputscale=  4.1749   lengthscale=  5.5146
# Iter   6/ 30 Loss=   4.344   outputscale= 17.9138   lengthscale=  5.1690   outputscale= 11.6502   lengthscale=  8.9125   outputscale=  4.1633   lengthscale=  5.5193
# Iter   6/ 30 Loss=   4.344   outputscale= 17.9478   lengthscale=  5.1614   outputscale= 11.6872   lengthscale=  8.9507   outputscale=  4.1474   lengthscale=  5.5237
# Iter   6/ 30 Loss=   4.344   outputscale= 17.9840   lengthscale=  5.1550   outputscale= 11.7265   lengthscale=  8.9921   outputscale=  4.1270   lengthscale=  5.5280
# Iter   6/ 30 Loss=   4.344   outputscale= 18.0216   lengthscale=  5.1496   outputscale= 11.7673   lengthscale=  9.0357   outputscale=  4.1023   lengthscale=  5.5321
# Iter   6/ 30 Loss=   4.344   outputscale= 18.0597   lengthscale=  5.1453   outputscale= 11.8083   lengthscale=  9.0803   outputscale=  4.0740   lengthscale=  5.5358
# Iter   6/ 30 Loss=   4.344   outputscale= 18.0973   lengthscale=  5.1420   outputscale= 11.8487   lengthscale=  9.1247   outputscale=  4.0425   lengthscale=  5.5390
# Iter   6/ 30 Loss=   4.344   outputscale= 18.1340   lengthscale=  5.1395   outputscale= 11.8878   lengthscale=  9.1684   outputscale=  4.0084   lengthscale=  5.5417
# Iter   6/ 30 Loss=   4.343   outputscale= 18.1696   lengthscale=  5.1377   outputscale= 11.9254   lengthscale=  9.2110   outputscale=  3.9717   lengthscale=  5.5438
# Iter   6/ 30 Loss=   4.343   outputscale= 18.2042   lengthscale=  5.1364   outputscale= 11.9617   lengthscale=  9.2526   outputscale=  3.9322   lengthscale=  5.5454
# Iter   6/ 30 Loss=   4.343   outputscale= 18.2381   lengthscale=  5.1356   outputscale= 11.9968   lengthscale=  9.2933   outputscale=  3.8893   lengthscale=  5.5464
# Iter   6/ 30 Loss=   4.343   outputscale= 18.2714   lengthscale=  5.1351   outputscale= 12.0308   lengthscale=  9.3332   outputscale=  3.8425   lengthscale=  5.5467
# Iter   6/ 30 Loss=   4.343   outputscale= 18.3044   lengthscale=  5.1350   outputscale= 12.0636   lengthscale=  9.3721   outputscale=  3.7909   lengthscale=  5.5464
# Iter   7/ 30 Loss=   4.343   outputscale= 18.3370   lengthscale=  5.1354   outputscale= 12.0953   lengthscale=  9.4096   outputscale=  3.7340   lengthscale=  5.5452
# Iter   7/ 30 Loss=   4.343   outputscale= 18.3690   lengthscale=  5.1366   outputscale= 12.1256   lengthscale=  9.4450   outputscale=  3.6718   lengthscale=  5.5432
# Iter   7/ 30 Loss=   4.343   outputscale= 18.3999   lengthscale=  5.1384   outputscale= 12.1536   lengthscale=  9.4777   outputscale=  3.6057   lengthscale=  5.5402
# Iter   7/ 30 Loss=   4.343   outputscale= 18.4287   lengthscale=  5.1410   outputscale= 12.1788   lengthscale=  9.5066   outputscale=  3.5374   lengthscale=  5.5365
# Iter   7/ 30 Loss=   4.343   outputscale= 18.4547   lengthscale=  5.1442   outputscale= 12.2004   lengthscale=  9.5311   outputscale=  3.4689   lengthscale=  5.5319
# Iter   7/ 30 Loss=   4.343   outputscale= 18.4773   lengthscale=  5.1481   outputscale= 12.2180   lengthscale=  9.5508   outputscale=  3.4018   lengthscale=  5.5268
# Iter   7/ 30 Loss=   4.343   outputscale= 18.4962   lengthscale=  5.1525   outputscale= 12.2315   lengthscale=  9.5656   outputscale=  3.3379   lengthscale=  5.5211
# Iter   7/ 30 Loss=   4.343   outputscale= 18.5113   lengthscale=  5.1573   outputscale= 12.2411   lengthscale=  9.5758   outputscale=  3.2786   lengthscale=  5.5152
# Iter   7/ 30 Loss=   4.343   outputscale= 18.5227   lengthscale=  5.1624   outputscale= 12.2471   lengthscale=  9.5817   outputscale=  3.2251   lengthscale=  5.5093
# Iter   7/ 30 Loss=   4.343   outputscale= 18.5310   lengthscale=  5.1676   outputscale= 12.2502   lengthscale=  9.5841   outputscale=  3.1779   lengthscale=  5.5036
# Iter   7/ 30 Loss=   4.343   outputscale= 18.5367   lengthscale=  5.1726   outputscale= 12.2510   lengthscale=  9.5839   outputscale=  3.1372   lengthscale=  5.4981
# Iter   7/ 30 Loss=   4.343   outputscale= 18.5403   lengthscale=  5.1775   outputscale= 12.2503   lengthscale=  9.5819   outputscale=  3.1027   lengthscale=  5.4931
# Iter   7/ 30 Loss=   4.343   outputscale= 18.5426   lengthscale=  5.1821   outputscale= 12.2487   lengthscale=  9.5787   outputscale=  3.0735   lengthscale=  5.4886
# Iter   7/ 30 Loss=   4.343   outputscale= 18.5440   lengthscale=  5.1864   outputscale= 12.2467   lengthscale=  9.5749   outputscale=  3.0490   lengthscale=  5.4845
# Iter   7/ 30 Loss=   4.343   outputscale= 18.5448   lengthscale=  5.1903   outputscale= 12.2445   lengthscale=  9.5709   outputscale=  3.0281   lengthscale=  5.4809
# Iter   7/ 30 Loss=   4.343   outputscale= 18.5454   lengthscale=  5.1941   outputscale= 12.2425   lengthscale=  9.5669   outputscale=  3.0103   lengthscale=  5.4776
# Iter   7/ 30 Loss=   4.343   outputscale= 18.5459   lengthscale=  5.1975   outputscale= 12.2407   lengthscale=  9.5630   outputscale=  2.9949   lengthscale=  5.4746
# Iter   7/ 30 Loss=   4.343   outputscale= 18.5464   lengthscale=  5.2008   outputscale= 12.2392   lengthscale=  9.5594   outputscale=  2.9814   lengthscale=  5.4719
# Iter   7/ 30 Loss=   4.343   outputscale= 18.5471   lengthscale=  5.2039   outputscale= 12.2380   lengthscale=  9.5560   outputscale=  2.9693   lengthscale=  5.4694
# Iter   7/ 30 Loss=   4.343   outputscale= 18.5480   lengthscale=  5.2069   outputscale= 12.2372   lengthscale=  9.5529   outputscale=  2.9585   lengthscale=  5.4671
# Iter   8/ 30 Loss=   4.343   outputscale= 18.5491   lengthscale=  5.2098   outputscale= 12.2368   lengthscale=  9.5500   outputscale=  2.9485   lengthscale=  5.4649
# Iter   8/ 30 Loss=   4.343   outputscale= 18.5506   lengthscale=  5.2126   outputscale= 12.2368   lengthscale=  9.5473   outputscale=  2.9394   lengthscale=  5.4628
# Iter   8/ 30 Loss=   4.343   outputscale= 18.5523   lengthscale=  5.2153   outputscale= 12.2373   lengthscale=  9.5448   outputscale=  2.9307   lengthscale=  5.4608
# Iter   8/ 30 Loss=   4.343   outputscale= 18.5545   lengthscale=  5.2181   outputscale= 12.2382   lengthscale=  9.5426   outputscale=  2.9226   lengthscale=  5.4588
# Iter   8/ 30 Loss=   4.343   outputscale= 18.5571   lengthscale=  5.2209   outputscale= 12.2397   lengthscale=  9.5405   outputscale=  2.9148   lengthscale=  5.4569
# Iter   8/ 30 Loss=   4.343   outputscale= 18.5602   lengthscale=  5.2238   outputscale= 12.2418   lengthscale=  9.5387   outputscale=  2.9072   lengthscale=  5.4550
# Iter   8/ 30 Loss=   4.343   outputscale= 18.5640   lengthscale=  5.2267   outputscale= 12.2445   lengthscale=  9.5371   outputscale=  2.8998   lengthscale=  5.4531
# Iter   8/ 30 Loss=   4.343   outputscale= 18.5685   lengthscale=  5.2297   outputscale= 12.2480   lengthscale=  9.5357   outputscale=  2.8926   lengthscale=  5.4512
# Iter   8/ 30 Loss=   4.343   outputscale= 18.5739   lengthscale=  5.2328   outputscale= 12.2524   lengthscale=  9.5346   outputscale=  2.8855   lengthscale=  5.4492
# Iter   8/ 30 Loss=   4.343   outputscale= 18.5802   lengthscale=  5.2360   outputscale= 12.2577   lengthscale=  9.5337   outputscale=  2.8785   lengthscale=  5.4472
# Iter   8/ 30 Loss=   4.343   outputscale= 18.5878   lengthscale=  5.2394   outputscale= 12.2643   lengthscale=  9.5332   outputscale=  2.8716   lengthscale=  5.4452
# Iter   8/ 30 Loss=   4.343   outputscale= 18.5967   lengthscale=  5.2430   outputscale= 12.2721   lengthscale=  9.5331   outputscale=  2.8647   lengthscale=  5.4432
# Iter   8/ 30 Loss=   4.343   outputscale= 18.6072   lengthscale=  5.2467   outputscale= 12.2815   lengthscale=  9.5334   outputscale=  2.8581   lengthscale=  5.4411
# Iter   8/ 30 Loss=   4.343   outputscale= 18.6195   lengthscale=  5.2506   outputscale= 12.2926   lengthscale=  9.5343   outputscale=  2.8515   lengthscale=  5.4389
# Iter   8/ 30 Loss=   4.343   outputscale= 18.6339   lengthscale=  5.2546   outputscale= 12.3059   lengthscale=  9.5358   outputscale=  2.8451   lengthscale=  5.4368
# Iter   8/ 30 Loss=   4.343   outputscale= 18.6508   lengthscale=  5.2588   outputscale= 12.3217   lengthscale=  9.5381   outputscale=  2.8387   lengthscale=  5.4346
# Iter   8/ 30 Loss=   4.343   outputscale= 18.6706   lengthscale=  5.2632   outputscale= 12.3405   lengthscale=  9.5413   outputscale=  2.8323   lengthscale=  5.4324
# Iter   8/ 30 Loss=   4.343   outputscale= 18.6934   lengthscale=  5.2677   outputscale= 12.3623   lengthscale=  9.5453   outputscale=  2.8262   lengthscale=  5.4303
# Iter   8/ 30 Loss=   4.343   outputscale= 18.7195   lengthscale=  5.2723   outputscale= 12.3875   lengthscale=  9.5504   outputscale=  2.8203   lengthscale=  5.4282
# Iter   8/ 30 Loss=   4.343   outputscale= 18.7490   lengthscale=  5.2770   outputscale= 12.4163   lengthscale=  9.5565   outputscale=  2.8146   lengthscale=  5.4261
# Iter   9/ 30 Loss=   4.343   outputscale= 18.7822   lengthscale=  5.2816   outputscale= 12.4489   lengthscale=  9.5638   outputscale=  2.8092   lengthscale=  5.4242
# Iter   9/ 30 Loss=   4.343   outputscale= 18.8195   lengthscale=  5.2863   outputscale= 12.4859   lengthscale=  9.5723   outputscale=  2.8037   lengthscale=  5.4224
# Iter   9/ 30 Loss=   4.343   outputscale= 18.8610   lengthscale=  5.2908   outputscale= 12.5273   lengthscale=  9.5821   outputscale=  2.7983   lengthscale=  5.4208
# Iter   9/ 30 Loss=   4.343   outputscale= 18.9069   lengthscale=  5.2952   outputscale= 12.5733   lengthscale=  9.5931   outputscale=  2.7927   lengthscale=  5.4194
# Iter   9/ 30 Loss=   4.343   outputscale= 18.9575   lengthscale=  5.2996   outputscale= 12.6245   lengthscale=  9.6054   outputscale=  2.7864   lengthscale=  5.4182
# Iter   9/ 30 Loss=   4.343   outputscale= 19.0141   lengthscale=  5.3038   outputscale= 12.6820   lengthscale=  9.6190   outputscale=  2.7785   lengthscale=  5.4172
# Iter   9/ 30 Loss=   4.343   outputscale= 19.0800   lengthscale=  5.3079   outputscale= 12.7493   lengthscale=  9.6343   outputscale=  2.7669   lengthscale=  5.4162
# Iter   9/ 30 Loss=   4.343   outputscale= 19.1604   lengthscale=  5.3122   outputscale= 12.8317   lengthscale=  9.6519   outputscale=  2.7492   lengthscale=  5.4152
# Iter   9/ 30 Loss=   4.343   outputscale= 19.2626   lengthscale=  5.3170   outputscale= 12.9366   lengthscale=  9.6726   outputscale=  2.7220   lengthscale=  5.4140
# Iter   9/ 30 Loss=   4.343   outputscale= 19.4107   lengthscale=  5.3235   outputscale= 13.0862   lengthscale=  9.6963   outputscale=  2.6710   lengthscale=  5.4114
# Iter   9/ 30 Loss=   4.343   outputscale= 19.6267   lengthscale=  5.3321   outputscale= 13.3041   lengthscale=  9.7276   outputscale=  2.5913   lengthscale=  5.4077
# Iter   9/ 30 Loss=   4.343   outputscale= 19.9388   lengthscale=  5.3432   outputscale= 13.6180   lengthscale=  9.7686   outputscale=  2.4709   lengthscale=  5.4023
# Iter   9/ 30 Loss=   4.343   outputscale= 20.4571   lengthscale=  5.3602   outputscale= 14.1385   lengthscale=  9.8310   outputscale=  2.2667   lengthscale=  5.3935
# Iter   9/ 30 Loss=   4.343   outputscale= 21.7829   lengthscale=  5.4011   outputscale= 15.4684   lengthscale=  9.9781   outputscale=  1.7594   lengthscale=  5.3709
# Iter   9/ 30 Loss=   4.342   outputscale= 23.1436   lengthscale=  5.4431   outputscale= 16.8330   lengthscale= 10.1267   outputscale=  1.2905   lengthscale=  5.3477
# Iter   9/ 30 Loss=   4.342   outputscale= 24.5072   lengthscale=  5.4856   outputscale= 18.2003   lengthscale= 10.2697   outputscale=  0.8954   lengthscale=  5.3242
# Iter   9/ 30 Loss=   4.342   outputscale= 26.7792   lengthscale=  5.5617   outputscale= 20.4675   lengthscale= 10.4290   outputscale=  0.4453   lengthscale=  5.2802
# Iter   9/ 30 Loss=   4.341   outputscale= 27.3726   lengthscale=  5.5821   outputscale= 21.0577   lengthscale= 10.4454   outputscale=  0.3697   lengthscale=  5.2682
# Iter   9/ 30 Loss=   4.341   outputscale= 29.0058   lengthscale=  5.6381   outputscale= 22.6796   lengthscale= 10.4520   outputscale=  0.2209   lengthscale=  5.2344
# Iter   9/ 30 Loss=   4.340   outputscale= 29.9657   lengthscale=  5.6679   outputscale= 23.6358   lengthscale= 10.4369   outputscale=  0.1656   lengthscale=  5.2165
# Iter  10/ 30 Loss=   4.340   outputscale= 30.6795   lengthscale=  5.6796   outputscale= 24.3677   lengthscale= 10.4253   outputscale=  0.1442   lengthscale=  5.2132
# Iter  10/ 30 Loss=   4.340   outputscale= 31.4279   lengthscale=  5.6840   outputscale= 25.1427   lengthscale= 10.4026   outputscale=  0.1279   lengthscale=  5.2129
# Iter  10/ 30 Loss=   4.339   outputscale= 32.1467   lengthscale=  5.6812   outputscale= 25.8906   lengthscale= 10.3699   outputscale=  0.1154   lengthscale=  5.2142
# Iter  10/ 30 Loss=   4.339   outputscale= 32.7878   lengthscale=  5.6717   outputscale= 26.5611   lengthscale= 10.3330   outputscale=  0.1066   lengthscale=  5.2171
# Iter  10/ 30 Loss=   4.338   outputscale= 33.3522   lengthscale=  5.6571   outputscale= 27.1536   lengthscale= 10.2947   outputscale=  0.1001   lengthscale=  5.2209
# Iter  10/ 30 Loss=   4.338   outputscale= 33.8561   lengthscale=  5.6385   outputscale= 27.6837   lengthscale= 10.2562   outputscale=  0.0949   lengthscale=  5.2250
# Iter  10/ 30 Loss=   4.337   outputscale= 34.3138   lengthscale=  5.6164   outputscale= 28.1660   lengthscale= 10.2182   outputscale=  0.0906   lengthscale=  5.2294
# Iter  10/ 30 Loss=   4.337   outputscale= 34.7377   lengthscale=  5.5910   outputscale= 28.6131   lengthscale= 10.1808   outputscale=  0.0868   lengthscale=  5.2338
# Iter  10/ 30 Loss=   4.337   outputscale= 35.1388   lengthscale=  5.5622   outputscale= 29.0362   lengthscale= 10.1439   outputscale=  0.0833   lengthscale=  5.2382
# Iter  10/ 30 Loss=   4.337   outputscale= 35.5277   lengthscale=  5.5297   outputscale= 29.4461   lengthscale= 10.1071   outputscale=  0.0800   lengthscale=  5.2427
# Iter  10/ 30 Loss=   4.336   outputscale= 35.9149   lengthscale=  5.4931   outputscale= 29.8537   lengthscale= 10.0703   outputscale=  0.0766   lengthscale=  5.2472
# Iter  10/ 30 Loss=   4.336   outputscale= 36.3076   lengthscale=  5.4523   outputscale= 30.2665   lengthscale= 10.0337   outputscale=  0.0731   lengthscale=  5.2517
# Iter  10/ 30 Loss=   4.336   outputscale= 36.6977   lengthscale=  5.4092   outputscale= 30.6758   lengthscale=  9.9992   outputscale=  0.0695   lengthscale=  5.2559
# Iter  10/ 30 Loss=   4.336   outputscale= 37.0399   lengthscale=  5.3708   outputscale= 31.0339   lengthscale=  9.9711   outputscale=  0.0661   lengthscale=  5.2592
# Iter  10/ 30 Loss=   4.336   outputscale= 37.2854   lengthscale=  5.3462   outputscale= 31.2887   lengthscale=  9.9501   outputscale=  0.0633   lengthscale=  5.2605
# Iter  10/ 30 Loss=   4.336   outputscale= 37.4621   lengthscale=  5.3306   outputscale= 31.4720   lengthscale=  9.9351   outputscale=  0.0614   lengthscale=  5.2615
# Iter  10/ 30 Loss=   4.336   outputscale= 37.6098   lengthscale=  5.3204   outputscale= 31.6245   lengthscale=  9.9213   outputscale=  0.0597   lengthscale=  5.2619
# Iter  10/ 30 Loss=   4.336   outputscale= 37.7465   lengthscale=  5.3119   outputscale= 31.7665   lengthscale=  9.9094   outputscale=  0.0585   lengthscale=  5.2628
# Iter  10/ 30 Loss=   4.336   outputscale= 37.8767   lengthscale=  5.3067   outputscale= 31.9008   lengthscale=  9.8958   outputscale=  0.0573   lengthscale=  5.2632
# Iter  10/ 30 Loss=   4.336   outputscale= 38.0211   lengthscale=  5.2982   outputscale= 32.0533   lengthscale=  9.8866   outputscale=  0.0567   lengthscale=  5.2654
# Iter  11/ 30 Loss=   4.336   outputscale= 38.1697   lengthscale=  5.2969   outputscale= 32.2055   lengthscale=  9.8688   outputscale=  0.0552   lengthscale=  5.2653
# Iter  11/ 30 Loss=   4.336   outputscale= 38.3273   lengthscale=  5.2897   outputscale= 32.3720   lengthscale=  9.8596   outputscale=  0.0547   lengthscale=  5.2676
# Iter  11/ 30 Loss=   4.336   outputscale= 38.4462   lengthscale=  5.2881   outputscale= 32.4957   lengthscale=  9.8484   outputscale=  0.0540   lengthscale=  5.2685
# Iter  11/ 30 Loss=   4.336   outputscale= 38.5566   lengthscale=  5.2859   outputscale= 32.6115   lengthscale=  9.8399   outputscale=  0.0536   lengthscale=  5.2697
# Iter  11/ 30 Loss=   4.336   outputscale= 38.6582   lengthscale=  5.2849   outputscale= 32.7180   lengthscale=  9.8314   outputscale=  0.0532   lengthscale=  5.2708
# Iter  11/ 30 Loss=   4.336   outputscale= 38.7567   lengthscale=  5.2836   outputscale= 32.8215   lengthscale=  9.8242   outputscale=  0.0529   lengthscale=  5.2720
# Iter  11/ 30 Loss=   4.336   outputscale= 38.8481   lengthscale=  5.2829   outputscale= 32.9175   lengthscale=  9.8174   outputscale=  0.0526   lengthscale=  5.2731
# Iter  11/ 30 Loss=   4.336   outputscale= 38.9363   lengthscale=  5.2820   outputscale= 33.0103   lengthscale=  9.8116   outputscale=  0.0524   lengthscale=  5.2742
# Iter  11/ 30 Loss=   4.336   outputscale= 39.0182   lengthscale=  5.2816   outputscale= 33.0962   lengthscale=  9.8062   outputscale=  0.0522   lengthscale=  5.2752
# Iter  11/ 30 Loss=   4.336   outputscale= 39.0970   lengthscale=  5.2809   outputscale= 33.1790   lengthscale=  9.8015   outputscale=  0.0520   lengthscale=  5.2761
# Iter  11/ 30 Loss=   4.336   outputscale= 39.1698   lengthscale=  5.2806   outputscale= 33.2554   lengthscale=  9.7972   outputscale=  0.0518   lengthscale=  5.2769
# Iter  11/ 30 Loss=   4.336   outputscale= 39.2397   lengthscale=  5.2801   outputscale= 33.3288   lengthscale=  9.7935   outputscale=  0.0517   lengthscale=  5.2777
# Iter  11/ 30 Loss=   4.336   outputscale= 39.3040   lengthscale=  5.2798   outputscale= 33.3962   lengthscale=  9.7900   outputscale=  0.0515   lengthscale=  5.2784
# Iter  11/ 30 Loss=   4.336   outputscale= 39.3657   lengthscale=  5.2794   outputscale= 33.4608   lengthscale=  9.7871   outputscale=  0.0514   lengthscale=  5.2790
# Iter  11/ 30 Loss=   4.336   outputscale= 39.4223   lengthscale=  5.2793   outputscale= 33.5200   lengthscale=  9.7844   outputscale=  0.0512   lengthscale=  5.2795
# Iter  11/ 30 Loss=   4.336   outputscale= 39.4764   lengthscale=  5.2790   outputscale= 33.5767   lengthscale=  9.7821   outputscale=  0.0511   lengthscale=  5.2800
# Iter  11/ 30 Loss=   4.336   outputscale= 39.5260   lengthscale=  5.2789   outputscale= 33.6284   lengthscale=  9.7798   outputscale=  0.0510   lengthscale=  5.2804
# Iter  11/ 30 Loss=   4.336   outputscale= 39.5735   lengthscale=  5.2787   outputscale= 33.6780   lengthscale=  9.7780   outputscale=  0.0509   lengthscale=  5.2808
# Iter  11/ 30 Loss=   4.336   outputscale= 39.6167   lengthscale=  5.2787   outputscale= 33.7230   lengthscale=  9.7763   outputscale=  0.0508   lengthscale=  5.2811
# Iter  11/ 30 Loss=   4.336   outputscale= 39.6586   lengthscale=  5.2785   outputscale= 33.7667   lengthscale=  9.7749   outputscale=  0.0507   lengthscale=  5.2814
# Iter  12/ 30 Loss=   4.336   outputscale= 39.6960   lengthscale=  5.2786   outputscale= 33.8055   lengthscale=  9.7734   outputscale=  0.0506   lengthscale=  5.2816
# Iter  12/ 30 Loss=   4.336   outputscale= 39.7331   lengthscale=  5.2784   outputscale= 33.8441   lengthscale=  9.7724   outputscale=  0.0505   lengthscale=  5.2818
# Iter  12/ 30 Loss=   4.336   outputscale= 39.7654   lengthscale=  5.2786   outputscale= 33.8776   lengthscale=  9.7711   outputscale=  0.0504   lengthscale=  5.2819
# Iter  12/ 30 Loss=   4.336   outputscale= 39.7975   lengthscale=  5.2785   outputscale= 33.9109   lengthscale=  9.7703   outputscale=  0.0503   lengthscale=  5.2821
# Iter  12/ 30 Loss=   4.336   outputscale= 39.8252   lengthscale=  5.2787   outputscale= 33.9395   lengthscale=  9.7694   outputscale=  0.0503   lengthscale=  5.2822
# Iter  12/ 30 Loss=   4.336   outputscale= 39.8524   lengthscale=  5.2786   outputscale= 33.9677   lengthscale=  9.7688   outputscale=  0.0502   lengthscale=  5.2823
# Iter  12/ 30 Loss=   4.336   outputscale= 39.8764   lengthscale=  5.2787   outputscale= 33.9923   lengthscale=  9.7681   outputscale=  0.0502   lengthscale=  5.2824
# Iter  12/ 30 Loss=   4.336   outputscale= 39.8999   lengthscale=  5.2786   outputscale= 34.0166   lengthscale=  9.7676   outputscale=  0.0501   lengthscale=  5.2824
# Iter  12/ 30 Loss=   4.336   outputscale= 39.9207   lengthscale=  5.2788   outputscale= 34.0379   lengthscale=  9.7670   outputscale=  0.0500   lengthscale=  5.2824
# Iter  12/ 30 Loss=   4.336   outputscale= 39.9412   lengthscale=  5.2787   outputscale= 34.0589   lengthscale=  9.7667   outputscale=  0.0500   lengthscale=  5.2824
# Iter  12/ 30 Loss=   4.336   outputscale= 39.9593   lengthscale=  5.2788   outputscale= 34.0774   lengthscale=  9.7663   outputscale=  0.0500   lengthscale=  5.2824
# Iter  12/ 30 Loss=   4.336   outputscale= 39.9770   lengthscale=  5.2788   outputscale= 34.0955   lengthscale=  9.7660   outputscale=  0.0499   lengthscale=  5.2824
# Iter  12/ 30 Loss=   4.336   outputscale= 39.9927   lengthscale=  5.2789   outputscale= 34.1114   lengthscale=  9.7658   outputscale=  0.0499   lengthscale=  5.2824
# Iter  12/ 30 Loss=   4.336   outputscale= 40.0078   lengthscale=  5.2789   outputscale= 34.1267   lengthscale=  9.7656   outputscale=  0.0498   lengthscale=  5.2824
# Iter  12/ 30 Loss=   4.336   outputscale= 40.0212   lengthscale=  5.2790   outputscale= 34.1403   lengthscale=  9.7654   outputscale=  0.0498   lengthscale=  5.2823
# Iter  12/ 30 Loss=   4.336   outputscale= 40.0339   lengthscale=  5.2791   outputscale= 34.1531   lengthscale=  9.7652   outputscale=  0.0498   lengthscale=  5.2823
# Iter  12/ 30 Loss=   4.336   outputscale= 40.0454   lengthscale=  5.2792   outputscale= 34.1647   lengthscale=  9.7651   outputscale=  0.0498   lengthscale=  5.2822
# Iter  12/ 30 Loss=   4.336   outputscale= 40.0560   lengthscale=  5.2792   outputscale= 34.1754   lengthscale=  9.7650   outputscale=  0.0497   lengthscale=  5.2822
# Iter  12/ 30 Loss=   4.336   outputscale= 40.0659   lengthscale=  5.2793   outputscale= 34.1852   lengthscale=  9.7650   outputscale=  0.0497   lengthscale=  5.2821
# Iter  12/ 30 Loss=   4.336   outputscale= 40.0749   lengthscale=  5.2794   outputscale= 34.1943   lengthscale=  9.7649   outputscale=  0.0497   lengthscale=  5.2820
# Iter  13/ 30 Loss=   4.336   outputscale= 40.0832   lengthscale=  5.2795   outputscale= 34.2026   lengthscale=  9.7649   outputscale=  0.0497   lengthscale=  5.2820
# Iter  13/ 30 Loss=   4.336   outputscale= 40.0908   lengthscale=  5.2795   outputscale= 34.2102   lengthscale=  9.7649   outputscale=  0.0497   lengthscale=  5.2819
# Iter  13/ 30 Loss=   4.336   outputscale= 40.0977   lengthscale=  5.2796   outputscale= 34.2171   lengthscale=  9.7649   outputscale=  0.0496   lengthscale=  5.2819
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1041   lengthscale=  5.2797   outputscale= 34.2234   lengthscale=  9.7649   outputscale=  0.0496   lengthscale=  5.2818
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1098   lengthscale=  5.2797   outputscale= 34.2292   lengthscale=  9.7649   outputscale=  0.0496   lengthscale=  5.2817
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1151   lengthscale=  5.2798   outputscale= 34.2343   lengthscale=  9.7650   outputscale=  0.0496   lengthscale=  5.2817
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1198   lengthscale=  5.2799   outputscale= 34.2390   lengthscale=  9.7650   outputscale=  0.0496   lengthscale=  5.2816
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1240   lengthscale=  5.2799   outputscale= 34.2432   lengthscale=  9.7651   outputscale=  0.0496   lengthscale=  5.2815
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1278   lengthscale=  5.2800   outputscale= 34.2470   lengthscale=  9.7651   outputscale=  0.0496   lengthscale=  5.2815
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1312   lengthscale=  5.2800   outputscale= 34.2503   lengthscale=  9.7652   outputscale=  0.0496   lengthscale=  5.2814
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1343   lengthscale=  5.2801   outputscale= 34.2533   lengthscale=  9.7652   outputscale=  0.0496   lengthscale=  5.2814
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1369   lengthscale=  5.2801   outputscale= 34.2559   lengthscale=  9.7653   outputscale=  0.0496   lengthscale=  5.2813
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1393   lengthscale=  5.2802   outputscale= 34.2582   lengthscale=  9.7654   outputscale=  0.0496   lengthscale=  5.2813
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1413   lengthscale=  5.2802   outputscale= 34.2602   lengthscale=  9.7654   outputscale=  0.0496   lengthscale=  5.2812
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1431   lengthscale=  5.2803   outputscale= 34.2619   lengthscale=  9.7655   outputscale=  0.0496   lengthscale=  5.2812
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1446   lengthscale=  5.2803   outputscale= 34.2634   lengthscale=  9.7656   outputscale=  0.0496   lengthscale=  5.2811
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1459   lengthscale=  5.2803   outputscale= 34.2646   lengthscale=  9.7656   outputscale=  0.0496   lengthscale=  5.2811
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1470   lengthscale=  5.2804   outputscale= 34.2657   lengthscale=  9.7657   outputscale=  0.0496   lengthscale=  5.2811
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1479   lengthscale=  5.2804   outputscale= 34.2666   lengthscale=  9.7657   outputscale=  0.0495   lengthscale=  5.2810
# Iter  13/ 30 Loss=   4.336   outputscale= 40.1486   lengthscale=  5.2804   outputscale= 34.2673   lengthscale=  9.7658   outputscale=  0.0495   lengthscale=  5.2810
# Iter  14/ 30 Loss=   4.336   outputscale= 40.1486   lengthscale=  5.2804   outputscale= 34.2673   lengthscale=  9.7658   outputscale=  0.0495   lengthscale=  5.2810
# Iter  14/ 30 Loss=   4.336   outputscale= 40.1493   lengthscale=  5.2805   outputscale= 34.2679   lengthscale=  9.7659   outputscale=  0.0495   lengthscale=  5.2810
# Iter  15/ 30 Loss=   4.336   outputscale= 40.1493   lengthscale=  5.2805   outputscale= 34.2679   lengthscale=  9.7659   outputscale=  0.0495   lengthscale=  5.2810
# Iter  15/ 30 Loss=   4.336   outputscale= 40.1499   lengthscale=  5.2805   outputscale= 34.2685   lengthscale=  9.7659   outputscale=  0.0495   lengthscale=  5.2809
# Iter  16/ 30 Loss=   4.336   outputscale= 40.1499   lengthscale=  5.2805   outputscale= 34.2685   lengthscale=  9.7659   outputscale=  0.0495   lengthscale=  5.2809
# Iter  16/ 30 Loss=   4.336   outputscale= 40.1504   lengthscale=  5.2805   outputscale= 34.2690   lengthscale=  9.7659   outputscale=  0.0495   lengthscale=  5.2809
# Iter  17/ 30 Loss=   4.336   outputscale= 40.1504   lengthscale=  5.2805   outputscale= 34.2690   lengthscale=  9.7659   outputscale=  0.0495   lengthscale=  5.2809
# Iter  17/ 30 Loss=   4.336   outputscale= 40.1509   lengthscale=  5.2805   outputscale= 34.2695   lengthscale=  9.7660   outputscale=  0.0495   lengthscale=  5.2809
# Iter  18/ 30 Loss=   4.336   outputscale= 40.1509   lengthscale=  5.2805   outputscale= 34.2695   lengthscale=  9.7660   outputscale=  0.0495   lengthscale=  5.2809
# Iter  18/ 30 Loss=   4.336   outputscale= 40.1513   lengthscale=  5.2805   outputscale= 34.2699   lengthscale=  9.7660   outputscale=  0.0495   lengthscale=  5.2809
# Iter  19/ 30 Loss=   4.336   outputscale= 40.1513   lengthscale=  5.2805   outputscale= 34.2699   lengthscale=  9.7660   outputscale=  0.0495   lengthscale=  5.2809
# Iter  19/ 30 Loss=   4.336   outputscale= 40.1517   lengthscale=  5.2806   outputscale= 34.2702   lengthscale=  9.7660   outputscale=  0.0495   lengthscale=  5.2809
# Iter  20/ 30 Loss=   4.336   outputscale= 40.1517   lengthscale=  5.2806   outputscale= 34.2702   lengthscale=  9.7660   outputscale=  0.0495   lengthscale=  5.2809
# Iter  20/ 30 Loss=   4.336   outputscale= 40.1520   lengthscale=  5.2806   outputscale= 34.2705   lengthscale=  9.7661   outputscale=  0.0495   lengthscale=  5.2808
# Iter  21/ 30 Loss=   4.336   outputscale= 40.1520   lengthscale=  5.2806   outputscale= 34.2705   lengthscale=  9.7661   outputscale=  0.0495   lengthscale=  5.2808
# Iter  21/ 30 Loss=   4.336   outputscale= 40.1523   lengthscale=  5.2806   outputscale= 34.2708   lengthscale=  9.7661   outputscale=  0.0495   lengthscale=  5.2808
# Iter  22/ 30 Loss=   4.336   outputscale= 40.1523   lengthscale=  5.2806   outputscale= 34.2708   lengthscale=  9.7661   outputscale=  0.0495   lengthscale=  5.2808
# Iter  22/ 30 Loss=   4.336   outputscale= 40.1526   lengthscale=  5.2806   outputscale= 34.2711   lengthscale=  9.7661   outputscale=  0.0495   lengthscale=  5.2808
# Iter  23/ 30 Loss=   4.336   outputscale= 40.1526   lengthscale=  5.2806   outputscale= 34.2711   lengthscale=  9.7661   outputscale=  0.0495   lengthscale=  5.2808
# Iter  23/ 30 Loss=   4.336   outputscale= 40.1528   lengthscale=  5.2806   outputscale= 34.2713   lengthscale=  9.7661   outputscale=  0.0495   lengthscale=  5.2808
# Iter  24/ 30 Loss=   4.336   outputscale= 40.1528   lengthscale=  5.2806   outputscale= 34.2713   lengthscale=  9.7661   outputscale=  0.0495   lengthscale=  5.2808
# Iter  24/ 30 Loss=   4.336   outputscale= 40.1530   lengthscale=  5.2806   outputscale= 34.2715   lengthscale=  9.7662   outputscale=  0.0495   lengthscale=  5.2808
# Iter  25/ 30 Loss=   4.336   outputscale= 40.1530   lengthscale=  5.2806   outputscale= 34.2715   lengthscale=  9.7662   outputscale=  0.0495   lengthscale=  5.2808
# Iter  26/ 30 Loss=   4.336   outputscale= 40.1530   lengthscale=  5.2806   outputscale= 34.2715   lengthscale=  9.7662   outputscale=  0.0495   lengthscale=  5.2808
# Iter  27/ 30 Loss=   4.336   outputscale= 40.1530   lengthscale=  5.2806   outputscale= 34.2715   lengthscale=  9.7662   outputscale=  0.0495   lengthscale=  5.2808
# Iter  28/ 30 Loss=   4.336   outputscale= 40.1530   lengthscale=  5.2806   outputscale= 34.2715   lengthscale=  9.7662   outputscale=  0.0495   lengthscale=  5.2808
# Iter  29/ 30 Loss=   4.336   outputscale= 40.1530   lengthscale=  5.2806   outputscale= 34.2715   lengthscale=  9.7662   outputscale=  0.0495   lengthscale=  5.2808
# Iter  30/ 30 Loss=   4.336   outputscale= 40.1530   lengthscale=  5.2806   outputscale= 34.2715   lengthscale=  9.7662   outputscale=  0.0495   lengthscale=  5.2808

# %%
for name, param in model.named_parameters():
    print(name, param.shape, param.requires_grad)
    
print()
print('Consrain parameter:')
for name, constraint in model.named_constraints():
    print(name, constraint)
# Out:
# mean.raw_constant torch.Size([]) False
# covar.raw_outputscale torch.Size([]) True
# covar.base_kernel.kernels.0.raw_lengthscale torch.Size([1, 1]) True
# covar.base_kernel.kernels.1.raw_outputscale torch.Size([]) True
# covar.base_kernel.kernels.1.base_kernel.kernels.0.raw_lengthscale torch.Size([1, 1]) True
# covar.base_kernel.kernels.1.base_kernel.kernels.1.raw_outputscale torch.Size([]) True
# covar.base_kernel.kernels.1.base_kernel.kernels.1.base_kernel.raw_lengthscale torch.Size([1, 1]) True
#
# Consrain parameter:
# covar.raw_outputscale_constraint Positive()
# covar.base_kernel.kernels.0.raw_lengthscale_constraint Positive()
# covar.base_kernel.kernels.1.raw_outputscale_constraint Positive()
# covar.base_kernel.kernels.1.base_kernel.kernels.0.raw_lengthscale_constraint Positive()
# covar.base_kernel.kernels.1.base_kernel.kernels.1.raw_outputscale_constraint Positive()
# covar.base_kernel.kernels.1.base_kernel.kernels.1.base_kernel.raw_lengthscale_constraint Positive()

# %%
print(
    model.mean.constant.item(),
    model.covar.outputscale.item(),
    model.covar.base_kernel.lengthscale
)
# Out:
# 0.0 40.15299987792969 None

# %%
plt.figure()
plt.plot([l.item() for l in loss])
plt.xlabel("Iteration")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# msg = (
#     f"Iter {i+1:3d}/{Niter:3d} "
#     f"Loss={loss.item():8.3f} "
#     f"mean={model.mean.constant.item():8.4f} "
#     f"outputscale={model.covar.outputscale.item():8.4f} "
#     f"lengthscale={model.covar.base_kernel.lengthscale.item():8.4f}"
# )
#
# print(msg)
#
# print(
#     model.mean.constant.item(),
#     model.covar.raw_outputscale.item(),
#     model.covar.base_kernel.raw_lengthscale.item()
# )

# %%
# Get into evaluation (predictive posterior) mode
#model.eval()
#model.likelihood.eval()

# %%
# get inpaint model and inpainted data
with torch.no_grad():
    inp_y, mdl = model.inpaint(inp_flags, y_offset=y_offset, to_complex=True)
inp_y = inp_y.reshape(-1, Ntimes, Nfreqs)

# inp_y.reshape(-1, 2, 3) =》 把 GP 内部的 batch 形式重新恢复成（ Nbls,Ntimes, Nfreq)形式 
#=>之后也可再自行加1维,变成 # shape = (Npol, Nbls, Ntimes, Nfreq)
#                                 = (1,    1,    2,      3)

print(mdl)
mdl = mdl.reshape(-1, Ntimes, Nfreqs)  #同理
#mdl inpaint 所有点
#inp_y inpaint flag点
#return inp_y, mdl, model, y_offset
# Out:
# tensor([[-55.5036+113.9283j, -53.3273+113.3705j, -51.1484+112.7628j,
#           ...,  33.9410-23.4382j,  32.9248-24.0226j,
#           31.8909-24.5710j],
#         [-52.6937+112.0524j, -50.7807+111.7346j, -48.8534+111.3556j,
#           ...,  33.5868-25.2221j,  32.5532-26.0680j,
#           31.4981-26.8991j],
#         [-55.2135+113.5021j, -52.7679+113.0117j, -50.3238+112.4682j,
#           ...,  33.7885-25.3129j,  32.7586-26.0836j,
#           31.7050-26.8320j],
#         ...,
#         [-28.9683+109.5836j, -26.7935+108.9841j, -24.6167+108.3325j,
#           ...,  29.4051-26.7828j,  28.1839-27.5906j,
#           26.9433-28.3789j],
#         [-24.9410+109.5250j, -22.8699+108.8039j, -20.7993+108.0301j,
#           ...,  30.5833-28.1140j,  29.4454-28.7287j,
#           28.2897-29.3092j],
#         [-23.5588+110.4515j, -21.3908+109.5363j, -19.2258+108.5772j,
#           ...,  32.0077-26.7601j,  31.1608-27.5300j,
#           30.3078-28.2804j]], dtype=torch.complex128)

# %%
import numpy as np

def flags_to_fchans(flag_array):
    """
    Convert a 1D boolean flag array into a list of
    contiguous flagged channel ranges.

    Parameters
    ----------
    flag_array : ndarray of bool, shape (Nfreq,)

    Returns
    -------
    fchans : list of tuple
        Example:
        [(38, 41), (61, 61), (80, 80), (132, 155)]
    """
    idx = np.where(flag_array)[0]

    if len(idx) == 0:
        return []

    fchans = []
    start = prev = idx[0]

    for i in idx[1:]:
        if i == prev + 1:
            prev = i
        else:
            fchans.append((start, prev))
            start = prev = i

    fchans.append((start, prev))

    return fchans

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(2, 1, figsize=(10, 7), sharex=True)

# x range (MHz)
xlim = (freqs.min(), freqs.max())

# ==========================================
# Top panel
# ==========================================
ax = axes[0]

# Tick style
ax.tick_params(axis='both', which='major',
               labelsize=12, direction='in',
               length=6, width=1.2,
               top=True, right=True)

ax.tick_params(axis='both', which='minor',
               direction='in',
               length=3, width=1.0,
               top=True, right=True)

ax.minorticks_on()

# Flagged channels
fchans = flags_to_fchans(flags[0, 0, 1, :])
print(fchans)

for fc in fchans:
    ax.axvspan(
        freqs[fc[0]],
        freqs[fc[1]],
        color='k',
        alpha=0.2
    )

# Original data
vis = np.abs(eor_fg_data[0, 0, 1, :])

p0, = ax.plot(
    freqs,
    vis,
    lw=4.5,
    color='steelblue',
    alpha=0.9
)

# Inpainted model
mdl_abs = np.abs(mdl[0, 1, :])

p1, = ax.plot(
    freqs,
    mdl_abs,
    lw=1.5,
    color='gold',
    ls='--'
)

# Legend patch
r = plt.Rectangle((0, 0), 0, 0, color='k', alpha=0.2)

ax.legend(
    [p0, p1, r],
    ['Eor + Foreground data',
     'Inpainted model (Eor + Foreground)',
     'Flagged channels'],
    fontsize=13
)

# Automatic axis limits
ax.set_xlim(xlim)
ax.set_ylim(0, 1.1 * max(vis.max(), mdl_abs.max()))

ax.set_ylabel(r'$|V|$ [Jy]', fontsize=16)

# Thicker frame
for spine in ax.spines.values():
    spine.set_linewidth(1.3)

# ==========================================
# Bottom panel
# ==========================================
ax = axes[1]

ax.tick_params(axis='both', which='major',
               labelsize=12, direction='in',
               length=6, width=1.2,
               top=True, right=True)

ax.tick_params(axis='both', which='minor',
               direction='in',
               length=3, width=1.0,
               top=True, right=True)

ax.minorticks_on()

# Residual
resid = mdl[0, 1, :] - eor_fg_data[0, 0, 1, :]
resid_abs = np.abs(resid)  #/abs(mdl[0, 1, :])

ax.plot(
    freqs,
    resid_abs,
    color='k',
    lw=1.2
)

# Automatic limits
ax.set_xlim(xlim)
ax.set_ylim(0, 1.1 * resid_abs.max())

ax.set_xlabel(r'$\nu$ [MHz]', fontsize=16)
ax.set_ylabel(r'Residual [Jy]', fontsize=14)

for spine in ax.spines.values():
    spine.set_linewidth(1.3)

plt.tight_layout()
plt.show()
# Out:
# [(38, 41), (61, 61), (81, 81), (131, 133), (135, 135), (137, 150), (152, 152), (175, 177), (180, 181), (187, 187), (191, 191), (194, 195), (201, 201), (203, 203), (207, 213), (221, 227), (229, 229), (232, 232), (238, 238), (244, 244), (276, 276), (279, 280), (286, 286), (288, 288), (293, 294), (302, 302), (312, 313), (315, 315), (320, 321), (338, 338), (340, 340), (408, 409), (411, 411), (416, 416), (419, 419), (423, 423), (451, 451), (500, 501), (503, 503), (514, 521), (523, 523), (543, 543), (551, 553), (566, 568), (570, 575), (577, 577), (582, 584), (599, 599)]

# %%
 mdl[0, 1, :]

# %%
eor_fg_data[0, 0, 1, :]
