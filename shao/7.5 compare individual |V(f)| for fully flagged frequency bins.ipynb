# %% [markdown]
# # Inpainting with GPR-LIM
#
# June, 2026

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import glob
import sys

sys.path.append('/Users/alliswell48/radio_gpr_work/shao/gprlim')
import gprlim
from gprlim import kernels

from pyuvdata import UVData
import bayeslim as ba

# %%
torch.set_default_dtype(torch.float64)

# %%
sys.path.append('../')
import gp_utils

# %%
import gpytorch
gpytorch.settings.max_cholesky_size._set_value(1_000)

# %%
torch.set_default_dtype(torch.float64)
device = 'cpu'

# %%
#总数据：(Nbls, Ntimes, Nfreq, Npol)=(242,1600,600,4)
#这里的file (110,1600,600,4)，thus:110*(110+1)/2= 6105 个baseline，200组（每组位置矢量相同）
#(Nbls, Ntimes, Nfreq, Npol)=(1,200,400,1)

# %%
# specify frequency channels
# by default, use equal to or less than 200 time integrations
# by default, use about 300-400 frequency channels
freq_chans = range(200, 600)
time_ints = range(300, 500)

# pick a representative baseline to load and model (start with 0)
bl = (0, 1)

# %%
# specify data
dfile = 'gpr_data/version2/zen.h6c_idr2_validation.sum.uvh5' #需要自己产生redundant baselibne
#dfile = sorted(glob.glob('../zen.h6c_idr2_validation.24582*.sum.coupled.h5')) #已经自动包含redundant baselibne

# %%
# load autocorrelation and metadata
vd, meta = gp_utils.load_uvdata(
    dfile, bls=[(0, 0)], pols=['ee'], time_ints=time_ints, freq_chans=freq_chans,
) #取auto (0,0) baselines
autocorr = vd.data[0,0]  #不是取baselines,是去掉前两维-》[1, 1, 1, 200, 400]->[1, 200, 400] =(baselines,Ntimes, Nfreq)

# get antenna information
antp = meta['antp']
ants = list(antp.keys())
antpos = torch.stack(list(antp.values()))

# get baseline information
red_bls = meta['bls']
all_pols = meta['pols']
reds = meta['reds']
# 它的meta文件:包含ant所有的1/4,  6105 baselines;分为20组（每组位置矢量相同；
#但实际上‘zen.h6c_idr2_validation.sum.uvh5'只含有(0,n)代表组基线数据
#而上面的load_uvdata( bls=[(0, 0)])只加载了一组

# get noise standard deviation
#meta['times']:day->s
#meta['freqs']:Hz
#formla sigma^2 = Vii * Vjj / Delta t / Delta nu.
#=>sigma (noise standard deviation)= Vjj / np.sqrt(Delta t / Delta nu)
noise_amp = autocorr.real / np.sqrt(np.diff(meta['times'])[0]*24*3600 * np.diff(meta['freqs'])[0])

# %% [markdown]
# # load redundant data
#
# load a single redundant baseline

# %%
# pick a representative baseline to load and model (start with 0)
#bl = (0, 2)

# this gets the index in the redundant set that this baseline falls in
red_ind = np.where([bl in red for red in reds])[0][0] #bl 属于第几组
bls = reds[red_ind][:] #该组所有成员
bl_vec = antp[bls[0][1]] - antp[bls[0][0]] #bls是该组 所有baselines的 位置矢量bls,选bls[0]->bl = (0, 2)
bl_len = bl_vec.norm()  #bl = (0, 2) 的baselines长度

# %%
# load single baseline data
#bl = (0, 2)
#(Nbls, Ntimes, Nfreq, Npol)=(1,200,400,1)
vd, meta = gp_utils.load_uvdata(
    dfile,
    bls=bls,
    time_ints=time_ints,
    freq_chans=freq_chans,
    pols=['ee'],
    device=device,
)
freqs = meta['freqs'] / 1e6   #Hz-> GHz
lsts = meta['lsts']  #day
times = (meta['times'] - meta['times'][0]) * 24 * 3600  #day->s
Ntimes = len(times)
Nfreqs = len(freqs)
reds = meta['reds']   #所有baselibe编号；包括redudant，虽然只有(0,n)的baseline有数据，其他没有
# Out:
# Antenna pair (1, 2) does not have any data associated with it.
# Antenna pair (2, 3) does not have any data associated with it.
# Antenna pair (3, 4) does not have any data associated with it.
# Antenna pair (4, 5) does not have any data associated with it.
# Antenna pair (5, 6) does not have any data associated with it.
# Antenna pair (6, 7) does not have any data associated with it.
# Antenna pair (7, 8) does not have any data associated with it.
# Antenna pair (8, 9) does not have any data associated with it.
# Antenna pair (9, 10) does not have any data associated with it.
# Antenna pair (11, 12) does not have any data associated with it.
# Antenna pair (12, 13) does not have any data associated with it.
# Antenna pair (13, 14) does not have any data associated with it.
# Antenna pair (14, 15) does not have any data associated with it.
# Antenna pair (15, 16) does not have any data associated with it.
# Antenna pair (16, 17) does not have any data associated with it.
# Antenna pair (17, 18) does not have any data associated with it.
# Antenna pair (18, 19) does not have any data associated with it.
# Antenna pair (19, 20) does not have any data associated with it.
# Antenna pair (20, 21) does not have any data associated with it.
# Antenna pair (23, 24) does not have any data associated with it.
# Antenna pair (24, 25) does not have any data associated with it.
# Antenna pair (25, 26) does not have any data associated with it.
# Antenna pair (26, 27) does not have any data associated with it.
# Antenna pair (27, 28) does not have any data associated with it.
# Antenna pair (28, 29) does not have any data associated with it.
# Antenna pair (29, 30) does not have any data associated with it.
# Antenna pair (30, 31) does not have any data associated with it.
# Antenna pair (31, 32) does not have any data associated with it.
# Antenna pair (32, 33) does not have any data associated with it.
# Antenna pair (36, 37) does not have any data associated with it.
# Antenna pair (37, 38) does not have any data associated with it.
# Antenna pair (38, 39) does not have any data associated with it.
# Antenna pair (39, 40) does not have any data associated with it.
# Antenna pair (40, 41) does not have any data associated with it.
# Antenna pair (41, 42) does not have any data associated with it.
# Antenna pair (42, 43) does not have any data associated with it.
# Antenna pair (43, 44) does not have any data associated with it.
# Antenna pair (44, 45) does not have any data associated with it.
# Antenna pair (45, 46) does not have any data associated with it.
# Antenna pair (50, 51) does not have any data associated with it.
# Antenna pair (51, 52) does not have any data associated with it.
# Antenna pair (52, 53) does not have any data associated with it.
# Antenna pair (53, 54) does not have any data associated with it.
# Antenna pair (54, 55) does not have any data associated with it.
# Antenna pair (55, 56) does not have any data associated with it.
# Antenna pair (56, 57) does not have any data associated with it.
# Antenna pair (57, 58) does not have any data associated with it.
# Antenna pair (58, 59) does not have any data associated with it.
# Antenna pair (59, 60) does not have any data associated with it.
# Antenna pair (65, 66) does not have any data associated with it.
# Antenna pair (66, 67) does not have any data associated with it.
# Antenna pair (67, 68) does not have any data associated with it.
# Antenna pair (68, 69) does not have any data associated with it.
# Antenna pair (69, 70) does not have any data associated with it.
# Antenna pair (70, 71) does not have any data associated with it.
# Antenna pair (71, 72) does not have any data associated with it.
# Antenna pair (72, 73) does not have any data associated with it.
# Antenna pair (73, 74) does not have any data associated with it.
# Antenna pair (74, 75) does not have any data associated with it.
# Antenna pair (81, 82) does not have any data associated with it.
# Antenna pair (82, 83) does not have any data associated with it.
# Antenna pair (83, 84) does not have any data associated with it.
# Antenna pair (84, 85) does not have any data associated with it.
# Antenna pair (85, 86) does not have any data associated with it.
# Antenna pair (86, 87) does not have any data associated with it.
# Antenna pair (87, 88) does not have any data associated with it.
# Antenna pair (88, 89) does not have any data associated with it.
# Antenna pair (89, 90) does not have any data associated with it.
# Antenna pair (90, 91) does not have any data associated with it.
# Antenna pair (98, 99) does not have any data associated with it.
# Antenna pair (99, 100) does not have any data associated with it.
# Antenna pair (100, 101) does not have any data associated with it.
# Antenna pair (101, 102) does not have any data associated with it.
# Antenna pair (102, 103) does not have any data associated with it.
# Antenna pair (103, 104) does not have any data associated with it.
# Antenna pair (104, 105) does not have any data associated with it.
# Antenna pair (105, 106) does not have any data associated with it.
# Antenna pair (106, 107) does not have any data associated with it.
# Antenna pair (107, 108) does not have any data associated with it.
# Antenna pair (116, 117) does not have any data associated with it.
# Antenna pair (117, 118) does not have any data associated with it.
# Antenna pair (118, 119) does not have any data associated with it.
# Antenna pair (119, 120) does not have any data associated with it.
# Antenna pair (120, 121) does not have any data associated with it.
# Antenna pair (121, 122) does not have any data associated with it.
# Antenna pair (122, 123) does not have any data associated with it.
# Antenna pair (123, 124) does not have any data associated with it.
# Antenna pair (124, 125) does not have any data associated with it.
# Antenna pair (125, 126) does not have any data associated with it.
# Antenna pair (135, 136) does not have any data associated with it.
# Antenna pair (136, 137) does not have any data associated with it.
# Antenna pair (137, 138) does not have any data associated with it.
# Antenna pair (138, 139) does not have any data associated with it.
# Antenna pair (139, 140) does not have any data associated with it.
# Antenna pair (140, 141) does not have any data associated with it.
# Antenna pair (141, 142) does not have any data associated with it.
# Antenna pair (142, 143) does not have any data associated with it.
# Antenna pair (143, 144) does not have any data associated with it.
# Antenna pair (144, 145) does not have any data associated with it.

# %%
inflate_data = True
if inflate_data and vd.Nbls == 1:
    vd = vd.inflate_by_redundancy(bls=reds[red_ind]) #reds[red_ind]是bl = (0, 2)对应的组的所有redundant成员
    
#[1, 1, 1, 200, 400]->[1, 1, 90, 200, 400]

# %%
add_noise = False
if add_noise:
    vd.data += torch.randn_like(vd.data) * noise_amp * 1e-3

# %%
# look at how large the data is
print("size of data in MB: {:.1f}".format(vd.data.nbytes/1e6))
# Out:
# size of data in MB: 128.0

# %%
# plot the data (called a waterfall)
fig, axes = plt.subplots(1, 4, figsize=(16, 5))
fig.subplots_adjust(wspace=.05)
dstd = vd.data.std()

#[1, 1, 90, 200, 400] 
#vd.data[0,0,0] 意思是[0,0,0, 200, 400] 

# visibility amplitude (abs)
cax = axes[0].imshow(vd.data[0,0,0].abs(), aspect='auto', extent=[freqs[0], freqs[-1], Ntimes, 0])
axes[0].set_title("|V|", fontsize=18, pad=45); cbar = plt.colorbar(cax, ax=axes[0], location='top');
axes[0].set_xlabel('Frequency [MHz]'); axes[0].set_ylabel('Time integration [bin]');

# visibility real
cax = axes[1].imshow(vd.data[0,0,0].real, aspect='auto', extent=[freqs[0], freqs[-1], Ntimes, 0], cmap='seismic',
                     vmin=-dstd*5, vmax=dstd*5)
axes[1].set_title("real(V)", fontsize=18, pad=45); cbar = plt.colorbar(cax, ax=axes[1], location='top');
axes[1].set_xlabel('Frequency [MHz]'); axes[1].set_yticklabels([])

# visibility imag
cax = axes[2].imshow(vd.data[0,0,0].imag, aspect='auto', extent=[freqs[0], freqs[-1], Ntimes, 0], cmap='seismic',
                     vmin=-dstd*5, vmax=dstd*5)
axes[2].set_title("imag(V)", fontsize=18, pad=45); cbar = plt.colorbar(cax, ax=axes[2], location='top');
axes[2].set_xlabel('Frequency [MHz]'); axes[2].set_yticklabels([]);

# visibility phase
cax = axes[3].imshow(vd.data[0,0,0].angle(), aspect='auto', extent=[freqs[0], freqs[-1], Ntimes, 0], cmap='hsv')
axes[3].set_title("angle(V)", fontsize=18, pad=45); cbar = plt.colorbar(cax, ax=axes[3], location='top');
axes[3].set_xlabel('Frequency [MHz]'); axes[3].set_yticklabels([]);

# %%
from bayeslim.fft import FFT
# vd.data.shape [1, 1, 90, 200, 400]
FT1 = FFT(dim=-1, N=vd.data.shape[-1], ndim=2, window='bh', dx=(freqs[1]-freqs[0])/1e3)  
FT2 = FFT(dim=-2, N=vd.data.shape[-2], ndim=2, window='bh', dx=(lsts[1]-lsts[0])*12/np.pi*3600/1e3)  
# time-> unit 1000 second=> fft ->fringe rate: unit: mHz

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
#[1, 1, 90, 200, 400]-> 取baseline 0；[1, 1, , 200, 400]
#pytorch: [ 200, 400] 从右边开始broadcasting=> [ 1,1,200, 400]，所以ndim=2也可以
axes[0].imshow(FT1(vd.data)[0,0,0].abs().log10(), aspect='auto', interpolation='none', vmin=-1, vmax=5,
               extent=[FT1.freqs[0], FT1.freqs[-1], Ntimes, 0])
axes[0].set_xlim(-1000, 1000); axes[0].set_xlabel('delay [ns]'); axes[0].set_ylabel('time bin')

axes[1].imshow(FT2(vd.data)[0,0,0].abs().log10(), aspect='auto', interpolation='none', vmin=0, vmax=3,
               extent=[freqs[0], freqs[-1], FT2.freqs[-1], FT2.freqs[0]])
axes[1].set_ylim(-9, 9); axes[1].set_xlabel('frequency [MHz]'); axes[1].set_ylabel('fringe rate [mHz]')

axes[2].imshow(FT1(FT2(vd.data))[0,0,0].abs().log10(), aspect='auto', interpolation='none', vmin=-1, vmax=5,
               extent=[FT1.freqs[0], FT1.freqs[-1], FT2.freqs[-1], FT2.freqs[0]])
axes[2].set_xlim(-1200, 1200); axes[2].set_ylim(-11, 11);

# %%
import os

bl_name = f"bl_{bl[0]}_{bl[1]}"
freq_time_name = (
    f"freq_{freq_chans.start}_{freq_chans.stop}_"
    f"time_{time_ints.start}_{time_ints.stop}"
)

save_dir = os.path.join(
    "inpaint_results",
    bl_name,
    freq_time_name,
)

# %% [markdown]
# # 1. Individual visibility as a function of frequency: `V[time, baseline, frequency]`
#
#
#
# ### 1. For a more normal flagged slice such as `V[0, 0, :]`, the 2D method does not perform as well as the other algorithms.
#
# ### 2. For `["fullband_short_time"]`, the slice `V[0, 27, :]` is fully flagged across frequency. In this case, the `freq_1d` method fails completely, while the 2D methods perform significantly better than the other algorithms.

# %% [markdown]
# # 1. normal flagged : V(f)[0, 0, :]

# %%
import os
import torch
import matplotlib.pyplot as plt


# ==================================================
# 0. Helper: title style
# ==================================================

def add_flag_title(ax, flag_id, flag_name, subtitle, y=1.32):
    ax.text(
        0.5,
        y,
        f"Flag {flag_id}: {flag_name}",
        transform=ax.transAxes,
        ha="center",
        va="bottom",
        color="darkred",
        fontsize=12,
        fontweight="bold",
    )

    ax.text(
        0.5,
        y - 0.12,
        subtitle,
        transform=ax.transAxes,
        ha="center",
        va="bottom",
        color="black",
        fontsize=12,
    )


def shade_flagged_freqs(ax, flags, freqs, label="Flagged frequency region"):
    flag_freq = flags.any(dim=tuple(range(flags.ndim - 1))).detach().cpu()

    freqs_cpu = freqs.detach().cpu() if torch.is_tensor(freqs) else torch.tensor(freqs)

    df = freqs_cpu[1] - freqs_cpu[0]

    in_region = False
    start = None
    first_label = True

    for i, is_flag in enumerate(flag_freq):

        is_flag = bool(is_flag)

        if is_flag and not in_region:
            start = i
            in_region = True

        if in_region and ((not is_flag) or (i == len(flag_freq) - 1)):
            end = i if not is_flag else i + 1

            x0 = (freqs_cpu[start] - df / 2).item()
            x1 = (freqs_cpu[end - 1] + df / 2).item()

            ax.axvspan(
                x0,
                x1,
                alpha=0.18,
                color="gray",
                label=label if first_label else None,
            )

            first_label = False
            in_region = False


linestyles = ["-", "--", "-.", ":"]
markers = ["o", ".", "^", "."]
linewidths = [2.2, 2.0, 2.0, 2.3]


# ==================================================
# 1. Algorithms to compare
# ==================================================

Algorithm_names = [
    "freq_1d",
    "time_1d_freq_1d",
    "time_freq_2d",
    "time_freq_2d_freq_1d",
]


flag_types_all = [
    ["real"],
    ["narrowband_full_time"],
    ["wideband_full_time"],
    ["ultraband_short_time"],
    ["fullband_short_time"],
    ["narrowband_short_time"],
    ["narrowband_intermittent"],
]


# ==================================================
# Choose one time and one baseline
# ==================================================

time_id = 0
bl_id = 0


# ==================================================
# 2. Loop over flag cases
# ==================================================

for flag_id, flag_types in enumerate(flag_types_all, start=1):

    flag_name = "+".join(flag_types)
    save_path = os.path.join(save_dir, f"inpaint_{flag_name}.pt")

    result_this_flag = torch.load(save_path, map_location="cpu")

    flags = result_this_flag["flags"].to(device).bool()

    print("Loaded:", save_path)
    print(f"Flag {flag_id}: {flag_name}")
    print("flags shape:", flags.shape)

    # ==================================================
    # 2.1 Original data: one time and one baseline
    # ==================================================

    data_y = vd.data[0, 0].to(device)      # shape: (Ntimes, Nbls, Nfreqs)

    # 第 time_id 个 time、第 bl_id 个 baseline
    y_true = data_y[ bl_id,time_id, :].abs()

    # ==================================================
    # 3. Visibility as a function of frequency
    # ==================================================

    fig, ax = plt.subplots(1, 1, figsize=(10, 5))

    shade_flagged_freqs(ax, flags, freqs)

    ax.plot(
        freqs,
        y_true,
        label="Original data",
    )

    y_inp_dict = {}

    for Algorithm_id, Algorithm_name in enumerate(Algorithm_names, start=1):

        inp_y = result_this_flag["inpaint"][Algorithm_name]["inp_y"].to(device)

        # 第 time_id 个 time、第 bl_id 个 baseline
        y_inp = inp_y[ bl_id, time_id,:].abs()

        y_inp_dict[Algorithm_name] = y_inp

        ax.plot(
            freqs,
            y_inp,
            ls="--",
            label=f"Algorithm {Algorithm_id}: {Algorithm_name}",
        )

    ax.set_yscale("log")
    ax.set_xlabel("Frequency [MHz]")
    ax.set_ylabel(r"$|V(\nu)|$")

    add_flag_title(
        ax,
        flag_id,
        flag_name,
        subtitle=rf"$V(\nu)$ at time={time_id}, baseline={bl_id}",
        y=1.45,
    )

    ax.legend(
        loc="lower center",
        bbox_to_anchor=(0.5, 1.0),
        ncol=3,
        frameon=False,
        fontsize=10,
    )

    plt.tight_layout()
    plt.show()

    # ==================================================
    # 4. Fractional residual in V(frequency)
    # ==================================================

    fig, ax = plt.subplots(1, 1, figsize=(10, 5))

    shade_flagged_freqs(ax, flags, freqs)

    for Algorithm_id, Algorithm_name in enumerate(Algorithm_names, start=1):



        y_inp = y_inp_dict[Algorithm_name]

        frac_res = (y_inp - y_true).abs() / y_true.abs().clamp_min(1e-30)

        style_id = Algorithm_id - 1

        ax.plot(
            freqs,
            frac_res,
            ls=linestyles[style_id],
            marker=markers[style_id],
            markevery=20,
            linewidth=linewidths[style_id],
            markersize=4,
            label=f"Algorithm {Algorithm_id}: {Algorithm_name}",
        )

    ax.set_xlabel("Frequency [MHz]")
    ax.set_ylabel(
        r"$\left||V_{\rm data}(\nu)| - |V_{\rm inpainted}(\nu)|\right|"
        r"/|V_{\rm data}(\nu)|$"
    )

    add_flag_title(
        ax,
        flag_id,
        flag_name,
        subtitle=rf"Fractional residual in $V(\nu)$ at time={time_id}, baseline={bl_id}",
        y=1.45,
    )

    ax.legend(
        loc="lower center",
        bbox_to_anchor=(0.5, 1.0),
        ncol=2,
        frameon=False,
        fontsize=10,
    )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 2.fully flagged V(f)[0, 27, :]

# %%
import os
import torch
import matplotlib.pyplot as plt


# ==================================================
# 0. Helper: title style
# ==================================================

def add_flag_title(ax, flag_id, flag_name, subtitle, y=1.32):
    ax.text(
        0.5,
        y,
        f"Flag {flag_id}: {flag_name}",
        transform=ax.transAxes,
        ha="center",
        va="bottom",
        color="darkred",
        fontsize=12,
        fontweight="bold",
    )

    ax.text(
        0.5,
        y - 0.12,
        subtitle,
        transform=ax.transAxes,
        ha="center",
        va="bottom",
        color="black",
        fontsize=12,
    )


def shade_flagged_freqs(ax, flags, freqs, label="Flagged frequency region"):
    flag_freq = flags.any(dim=tuple(range(flags.ndim - 1))).detach().cpu()

    freqs_cpu = freqs.detach().cpu() if torch.is_tensor(freqs) else torch.tensor(freqs)

    df = freqs_cpu[1] - freqs_cpu[0]

    in_region = False
    start = None
    first_label = True

    for i, is_flag in enumerate(flag_freq):

        is_flag = bool(is_flag)

        if is_flag and not in_region:
            start = i
            in_region = True

        if in_region and ((not is_flag) or (i == len(flag_freq) - 1)):
            end = i if not is_flag else i + 1

            x0 = (freqs_cpu[start] - df / 2).item()
            x1 = (freqs_cpu[end - 1] + df / 2).item()

            ax.axvspan(
                x0,
                x1,
                alpha=0.18,
                color="gray",
                label=label if first_label else None,
            )

            first_label = False
            in_region = False


linestyles = ["-", "--", "-.", ":"]
markers = ["o", ".", "^", "."]
linewidths = [2.2, 2.0, 2.0, 2.3]


# ==================================================
# 1. Algorithms to compare
# ==================================================

Algorithm_names = [
    "freq_1d",
    "time_1d_freq_1d",
    "time_freq_2d",
    "time_freq_2d_freq_1d",
]


flag_types_all = [
    ["real"],
    ["narrowband_full_time"],
    ["wideband_full_time"],
    ["ultraband_short_time"],
    ["fullband_short_time"],
    ["narrowband_short_time"],
    ["narrowband_intermittent"],
]


# ==================================================
# Choose one time and one baseline
# ==================================================

time_id = 27
bl_id = 0


# ==================================================
# 2. Loop over flag cases
# ==================================================

for flag_id, flag_types in enumerate(flag_types_all, start=1):

    flag_name = "+".join(flag_types)
    save_path = os.path.join(save_dir, f"inpaint_{flag_name}.pt")

    result_this_flag = torch.load(save_path, map_location="cpu")

    flags = result_this_flag["flags"].to(device).bool()

    print("Loaded:", save_path)
    print(f"Flag {flag_id}: {flag_name}")
    print("flags shape:", flags.shape)

    # ==================================================
    # 2.1 Original data: one time and one baseline
    # ==================================================

    data_y = vd.data[0, 0].to(device)      # shape: (Ntimes, Nbls, Nfreqs)

    # 第 time_id 个 time、第 bl_id 个 baseline
    y_true = data_y[ bl_id,time_id, :].abs()

    # ==================================================
    # 3. Visibility as a function of frequency
    # ==================================================

    fig, ax = plt.subplots(1, 1, figsize=(10, 5))

    shade_flagged_freqs(ax, flags, freqs)

    ax.plot(
        freqs,
        y_true,
        label="Original data",
    )

    y_inp_dict = {}

    for Algorithm_id, Algorithm_name in enumerate(Algorithm_names, start=1):

        inp_y = result_this_flag["inpaint"][Algorithm_name]["inp_y"].to(device)

        # 第 time_id 个 time、第 bl_id 个 baseline
        y_inp = inp_y[bl_id,time_id,  :].abs()

        y_inp_dict[Algorithm_name] = y_inp

        ax.plot(
            freqs,
            y_inp,
            ls="--",
            label=f"Algorithm {Algorithm_id}: {Algorithm_name}",
        )

    ax.set_yscale("log")
    ax.set_xlabel("Frequency [MHz]")
    ax.set_ylabel(r"$|V(\nu)|$")

    add_flag_title(
        ax,
        flag_id,
        flag_name,
        subtitle=rf"$V(\nu)$ at time={time_id}, baseline={bl_id}",
        y=1.45,
    )

    ax.legend(
        loc="lower center",
        bbox_to_anchor=(0.5, 1.0),
        ncol=3,
        frameon=False,
        fontsize=10,
    )

    plt.tight_layout()
    plt.show()

    # ==================================================
    # 4. Fractional residual in V(frequency)
    # ==================================================

    fig, ax = plt.subplots(1, 1, figsize=(10, 5))

    shade_flagged_freqs(ax, flags, freqs)

    for Algorithm_id, Algorithm_name in enumerate(Algorithm_names, start=1):



        y_inp = y_inp_dict[Algorithm_name]

        frac_res = (y_inp - y_true).abs() / y_true.abs().clamp_min(1e-30)

        style_id = Algorithm_id - 1

        ax.plot(
            freqs,
            frac_res,
            ls=linestyles[style_id],
            marker=markers[style_id],
            markevery=20,
            linewidth=linewidths[style_id],
            markersize=4,
            label=f"Algorithm {Algorithm_id}: {Algorithm_name}",
        )

    ax.set_xlabel("Frequency [MHz]")
    ax.set_ylabel(
        r"$\left||V_{\rm data}(\nu)| - |V_{\rm inpainted}(\nu)|\right|"
        r"/|V_{\rm data}(\nu)|$"
    )

    add_flag_title(
        ax,
        flag_id,
        flag_name,
        subtitle=rf"Fractional residual in $V(\nu)$ at time={time_id}, baseline={bl_id}",
        y=1.45,
    )

    ax.legend(
        loc="lower center",
        bbox_to_anchor=(0.5, 1.0),
        ncol=2,
        frameon=False,
        fontsize=10,
    )

    plt.tight_layout()
    plt.show()
# Out:
# Loaded: inpaint_results/bl_0_1/freq_200_600_time_300_500/inpaint_real.pt
# Flag 1: real
# flags shape: torch.Size([1, 200, 400])
# Loaded: inpaint_results/bl_0_1/freq_200_600_time_300_500/inpaint_narrowband_full_time.pt
# Flag 2: narrowband_full_time
# flags shape: torch.Size([1, 200, 400])
# Loaded: inpaint_results/bl_0_1/freq_200_600_time_300_500/inpaint_wideband_full_time.pt
# Flag 3: wideband_full_time
# flags shape: torch.Size([1, 200, 400])
# Loaded: inpaint_results/bl_0_1/freq_200_600_time_300_500/inpaint_ultraband_short_time.pt
# Flag 4: ultraband_short_time
# flags shape: torch.Size([1, 200, 400])
# Loaded: inpaint_results/bl_0_1/freq_200_600_time_300_500/inpaint_fullband_short_time.pt
# Flag 5: fullband_short_time
# flags shape: torch.Size([1, 200, 400])
# Loaded: inpaint_results/bl_0_1/freq_200_600_time_300_500/inpaint_narrowband_short_time.pt
# Flag 6: narrowband_short_time
# flags shape: torch.Size([1, 200, 400])
# Loaded: inpaint_results/bl_0_1/freq_200_600_time_300_500/inpaint_narrowband_intermittent.pt
# Flag 7: narrowband_intermittent
# flags shape: torch.Size([1, 200, 400])

# %% [markdown]
# # 3. fullband_shortime

# %%
import os
import torch
import matplotlib.pyplot as plt


# ==================================================
# 0. Helper: title style
# ==================================================

def add_flag_title(ax, flag_id, flag_name, subtitle, y=1.32):
    ax.text(
        0.5,
        y,
        f"Flag {flag_id}: {flag_name}",
        transform=ax.transAxes,
        ha="center",
        va="bottom",
        color="darkred",
        fontsize=12,
        fontweight="bold",
    )

    ax.text(
        0.5,
        y - 0.12,
        subtitle,
        transform=ax.transAxes,
        ha="center",
        va="bottom",
        color="black",
        fontsize=12,
    )


def shade_flagged_freqs(ax, flags, freqs, label="Flagged frequency region"):
    flag_freq = flags.any(dim=tuple(range(flags.ndim - 1))).detach().cpu()

    freqs_cpu = freqs.detach().cpu() if torch.is_tensor(freqs) else torch.tensor(freqs)

    df = freqs_cpu[1] - freqs_cpu[0]

    in_region = False
    start = None
    first_label = True

    for i, is_flag in enumerate(flag_freq):

        is_flag = bool(is_flag)

        if is_flag and not in_region:
            start = i
            in_region = True

        if in_region and ((not is_flag) or (i == len(flag_freq) - 1)):
            end = i if not is_flag else i + 1

            x0 = (freqs_cpu[start] - df / 2).item()
            x1 = (freqs_cpu[end - 1] + df / 2).item()

            ax.axvspan(
                x0,
                x1,
                alpha=0.18,
                color="gray",
                label=label if first_label else None,
            )

            first_label = False
            in_region = False


linestyles = ["-", "--", "-.", ":"]
markers = ["o", ".", "^", "."]
linewidths = [2.2, 2.0, 2.0, 2.3]


# ==================================================
# 1. Algorithms to compare
# ==================================================

Algorithm_names = [
    "freq_1d",
    "time_1d_freq_1d",
    "time_freq_2d",
    "time_freq_2d_freq_1d",
]


flag_types_all = [
    #["real"],
    #["narrowband_full_time"],
    #["wideband_full_time"],
    #["ultraband_short_time"],
    ["fullband_short_time"],
    #["narrowband_short_time"],
    #["narrowband_intermittent"],
]


# ==================================================
# Choose one time and one baseline
# ==================================================

time_id = 27
bl_id = 0


# ==================================================
# 2. Loop over flag cases
# ==================================================

for flag_id, flag_types in enumerate(flag_types_all, start=1):

    flag_name = "+".join(flag_types)
    save_path = os.path.join(save_dir, f"inpaint_{flag_name}.pt")

    result_this_flag = torch.load(save_path, map_location="cpu")

    flags = result_this_flag["flags"].to(device).bool()

    print("Loaded:", save_path)
    print(f"Flag {flag_id}: {flag_name}")
    print("flags shape:", flags.shape)

    # ==================================================
    # 2.1 Original data: one time and one baseline
    # ==================================================

    data_y = vd.data[0, 0].to(device)      # shape: (Ntimes, Nbls, Nfreqs)

    # 第 time_id 个 time、第 bl_id 个 baseline
    y_true = data_y[ bl_id,time_id, :].abs()

    # ==================================================
    # 3. Visibility as a function of frequency
    # ==================================================

    fig, ax = plt.subplots(1, 1, figsize=(10, 5))

    shade_flagged_freqs(ax, flags, freqs)

    ax.plot(
        freqs,
        y_true,
        label="Original data",
    )

    y_inp_dict = {}

    for Algorithm_id, Algorithm_name in enumerate(Algorithm_names, start=1):

        inp_y = result_this_flag["inpaint"][Algorithm_name]["inp_y"].to(device)

        # 第 time_id 个 time、第 bl_id 个 baseline
        y_inp = inp_y[ bl_id, time_id,:].abs()

        y_inp_dict[Algorithm_name] = y_inp

        ax.plot(
            freqs,
            y_inp,
            ls="--",
            label=f"Algorithm {Algorithm_id}: {Algorithm_name}",
        )

    ax.set_yscale("log")
    ax.set_xlabel("Frequency [MHz]")
    ax.set_ylabel(r"$|V(\nu)|$")

    add_flag_title(
        ax,
        flag_id,
        flag_name,
        subtitle=rf"$V(\nu)$ at time={time_id}, baseline={bl_id}",
        y=1.45,
    )

    ax.legend(
        loc="lower center",
        bbox_to_anchor=(0.5, 1.0),
        ncol=3,
        frameon=False,
        fontsize=10,
    )

    plt.tight_layout()
    plt.show()

    # ==================================================
    # 4. Fractional residual in V(frequency)
    # ==================================================

    fig, ax = plt.subplots(1, 1, figsize=(10, 5))

    shade_flagged_freqs(ax, flags, freqs)

    for Algorithm_id, Algorithm_name in enumerate(Algorithm_names, start=1):

        # 只在 fullband_short_time 时跳过 freq_1d
        if flag_types == ["fullband_short_time"] and Algorithm_name == "freq_1d":
            continue

        y_inp = y_inp_dict[Algorithm_name]

        frac_res = (y_inp - y_true).abs() / y_true.abs().clamp_min(1e-30)

        style_id = Algorithm_id - 1

        ax.plot(
            freqs,
            frac_res,
            ls=linestyles[style_id],
            marker=markers[style_id],
            markevery=20,
            linewidth=linewidths[style_id],
            markersize=4,
            label=f"Algorithm {Algorithm_id}: {Algorithm_name}",
        )

    ax.set_xlabel("Frequency [MHz]")
    ax.set_ylabel(
        r"$\left||V_{\rm data}(\nu)| - |V_{\rm inpainted}(\nu)|\right|"
        r"/|V_{\rm data}(\nu)|$"
    )

    add_flag_title(
        ax,
        flag_id,
        flag_name,
        subtitle=rf"Fractional residual in $V(\nu)$ at time={time_id}, baseline={bl_id}",
        y=1.45,
    )

    ax.legend(
        loc="lower center",
        bbox_to_anchor=(0.5, 1.0),
        ncol=2,
        frameon=False,
        fontsize=10,
    )

    plt.tight_layout()
    plt.show()
# Out:
# Loaded: inpaint_results/bl_0_1/freq_200_600_time_300_500/inpaint_fullband_short_time.pt
# Flag 1: fullband_short_time
# flags shape: torch.Size([1, 200, 400])
